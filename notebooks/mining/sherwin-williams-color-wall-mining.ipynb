# %% [markdown]
# ## Mining Sherwin-William's Color Wall
#
# Using Selenium, BeautifulSoup and a little bit of patience!

# %%
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# Out:
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 4.9MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from selenium) (1.24.3)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [564 B]
# Get:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [819 B]
# Get:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:9 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [70.9 kB]
# Hit:11 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [119 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:14 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [20.6 kB]
# Get:15 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [31.7 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [5,391 B]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [676 kB]
# Get:20 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,710 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [8,456 B]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [21.0 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [971 kB]
# Get:24 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [774 kB]
# Get:25 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [823 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,292 kB]
# Get:27 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [10.4 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [4,227 B]
# Fetched 6,833 kB in 5s (1,356 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension adobe-flashplugin
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 143 not upgraded.
# Need to get 70.8 MB of archives.
# After this operation, 254 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 77.0.3865.90-0ubuntu0.18.04.1 [1,079 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 77.0.3865.90-0ubuntu0.18.04.1 [62.3 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 77.0.3865.90-0ubuntu0.18.04.1 [3,011 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 77.0.3865.90-0ubuntu0.18.04.1 [4,388 kB]
# Fetched 70.8 MB in 8s (8,645 kB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 131183 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_77.0.3865.90-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (77.0.3865.90-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_77.0.3865.90-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (77.0.3865.90-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_77.0.3865.90-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (77.0.3865.90-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_77.0.3865.90-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (77.0.3865.90-0ubuntu0.18.04.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up chromium-codecs-ffmpeg-extra (77.0.3865.90-0ubuntu0.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Setting up chromium-browser (77.0.3865.90-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (77.0.3865.90-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (77.0.3865.90-0ubuntu0.18.04.1) ...
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file

# %% [markdown]
# ## Prepare Selenium
#
# After downloading chromedriver from chromium, we set selenium to simulate a Chrome session. We need to do this because the color wall page of Sherwin-Williams is generated dynamically by Javascript. A simple `GET` request would just return the javascript code.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import sys
import re

# %%
sys.path.insert(0, '/usr/lib/chromium-browser/chromedriver')

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

chrome = webdriver.Chrome(
    'chromedriver', 
    options=options
)

# %% [markdown]
# ## Extract HTML Code
#
# By navigating to the page with Selenium, the Javascript is executed and we can retrieve the generated HTML with `execute_script`, which executes our Javascript code.

# %%
color_wall_webpage = (
    'https://www.sherwin-williams.com/visualizer#/active/color-wall'
)

chrome.get(color_wall_webpage)
color_wall_webpage_html = chrome.execute_script(
    "return document.body.innerHTML"
)

# initialize BS to run on color_wall_webpage_html:
soup = BeautifulSoup(color_wall_webpage_html, 'html.parser')

# %% [markdown]
# ## Retrieve Color Patches
#
# Luckily, all color patches in the Color Wall have a `sw-color-chip` attribute set to `::color`.

# %%
color_patches = soup.find_all('div', {'sw-color-chip': "::color"})

# filter any potential noise (patch without a color title)
color_patches = list(filter(lambda p: p.get('title'), color_patches))
colors = {
    color_patch.get('title'): 
      re.search(  # retrieve exactly the rgb value
          r'[(][^)]+[)]', 
          color_patch.get('style')
      ).group(0)

    for color_patch in color_patches
}

# %%
colors
# Out:
# {'SW 6840 Exuberant Pink': '(181, 77, 127)',
#  'SW 6855 Dragon Fruit': '(204, 97, 127)',
#  'SW 6862 Cherries Jubilee': '(171, 60, 81)',
#  'SW 6861 Radish': '(164, 46, 65)',
#  'SW 6866 Heartthrob': '(168, 46, 51)',
#  'SW 6868 Real Red': '(191, 45, 50)',
#  'SW 6871 Positive Red': '(173, 44, 52)',
#  'SW 6561 Teaberry': '(235, 209, 219)',
#  'SW 6568 Lighthearted Pink': '(237, 213, 221)',
#  'SW 6575 Priscilla': '(241, 211, 218)',
#  'SW 6582 Impatiens Petal': '(241, 210, 215)',
#  'SW 6589 Alyssum': '(242, 213, 215)',
#  'SW 6596 Bella Pink': '(241, 198, 196)',
#  'SW 6603 Oleander': '(242, 204, 197)',
#  'SW 6562 Irresistible': '(227, 192, 207)',
#  'SW 6569 Childlike': '(232, 192, 207)',
#  'SW 6576 Azalea Flower': '(239, 192, 203)',
#  'SW 6583 In the Pink': '(240, 188, 201)',
#  'SW 6590 Loveable': '(240, 193, 198)',
#  'SW 6597 Hopeful': '(240, 179, 178)',
#  'SW 6604 Youthful Coral': '(240, 175, 168)',
#  'SW 6563 Rosebay': '(203, 154, 173)',
#  'SW 6570 Haute Pink': '(216, 153, 177)',
#  'SW 6577 Jaipur Pink': '(227, 146, 161)',
#  'SW 6584 Cheery': '(235, 146, 163)',
#  'SW 6591 Amaryllis': '(237, 147, 157)',
#  'SW 6598 Dishy Coral': '(237, 145, 144)',
#  'SW 6605 Charisma': '(238, 148, 137)',
#  'SW 6564 Red Clover': '(184, 126, 147)',
#  'SW 6571 Cyclamen': '(196, 123, 149)',
#  'SW 6578 Tuberose': '(212, 124, 140)',
#  'SW 6585 Coming up Roses': '(221, 119, 136)',
#  'SW 6592 Grenadine': '(214, 105, 114)',
#  'SW 6599 Begonia': '(215, 108, 110)',
#  'SW 6606 Coral Reef': '(217, 118, 108)',
#  'SW 6565 Grandeur Plum': '(146, 87, 111)',
#  'SW 6572 Ruby Shade': '(162, 86, 111)',
#  'SW 6579 Gala Pink': '(176, 75, 99)',
#  'SW 6860 Eros Pink': '(200, 79, 104)',
#  'SW 6593 Coral Bells': '(187, 75, 81)',
#  'SW 6600 Enticing Red': '(183, 78, 79)',
#  'SW 6607 Red Tomato': '(178, 71, 67)',
#  'SW 6841 Dynamo': '(149, 61, 104)',
#  'SW 6573 Juneberry': '(133, 65, 88)',
#  'SW 6843 Hot': '(172, 67, 98)',
#  'SW 6586 Heartfelt': '(189, 76, 95)',
#  'SW 7588 Show Stopper': '(164, 46, 55)',
#  'SW 6601 Tanager': '(164, 56, 52)',
#  'SW 6608 Rave Red': '(161, 59, 52)',
#  'SW 6842 Forward Fuchsia': '(146, 52, 91)',
#  'SW 6566 Framboise': '(124, 54, 85)',
#  'SW 6580 Cerise': '(153, 50, 78)',
#  'SW 6587 Valentine': '(165, 58, 78)',
#  'SW 6594 Poinsettia': '(157, 55, 60)',
#  'SW 7587 Antique Red': '(159, 68, 66)',
#  'SW 7600 Bolero': '(144, 57, 52)',
#  'SW 6288 Rosebud': '(224, 205, 209)',
#  'SW 6295 Demure': '(232, 212, 213)',
#  'SW 6302 Innocence': '(235, 209, 207)',
#  'SW 6309 Charming Pink': '(237, 211, 210)',
#  'SW 6316 Rosy Outlook': '(235, 206, 203)',
#  'SW 6323 Romance': '(235, 207, 195)',
#  'SW 6330 Quaint Peche': '(234, 205, 193)',
#  'SW 6289 Delightful': '(210, 182, 190)',
#  'SW 6296 Fading Rose': '(218, 189, 193)',
#  'SW 6303 Rose Colored': '(220, 182, 181)',
#  'SW 6310 Lotus Flower': '(230, 189, 189)',
#  'SW 6317 Gracious Rose': '(227, 183, 177)',
#  'SW 6324 Mellow Coral': '(227, 181, 168)',
#  'SW 6331 Smoky Salmon': '(226, 182, 167)',
#  'SW 6290 Rosé': '(185, 149, 161)',
#  'SW 6297 Rose Embroidery': '(199, 158, 162)',
#  'SW 6304 Pressed Flower': '(195, 147, 147)',
#  'SW 6311 Memorable Rose': '(207, 138, 141)',
#  'SW 6318 Resounding Rose': '(205, 142, 137)',
#  'SW 6325 Constant Coral': '(205, 142, 127)',
#  'SW 6332 Coral Island': '(206, 147, 130)',
#  'SW 6291 Moss Rose': '(158, 109, 121)',
#  "SW 9001 Audrey's Blush": '(174, 128, 135)',
#  "SW 9002 Carley's Rose": '(168, 115, 118)',
#  "SW 9003 Rita's Rouge": '(186, 113, 118)',
#  'SW 9004 Coral Rose': '(195, 127, 122)',
#  'SW 9005 Coral Clay': '(191, 121, 110)',
#  'SW 9006 Rojo Dust': '(181, 116, 102)',
#  'SW 6292 Berry Bush': '(141, 88, 105)',
#  'SW 6298 Concerto': '(158, 107, 117)',
#  'SW 6305 Rambling Rose': '(153, 93, 98)',
#  'SW 6312 Redbud': '(173, 94, 101)',
#  'SW 6319 Reddish': '(181, 105, 102)',
#  'SW 6326 Henna Shade': '(179, 103, 93)',
#  'SW 6333 Foxy': '(168, 94, 83)',
#  'SW 6293 Fabulous Grape': '(109, 52, 79)',
#  'SW 6299 Aged Wine': '(137, 84, 96)',
#  'SW 6306 Cordial': '(134, 76, 82)',
#  'SW 6313 Kirsch Red': '(151, 73, 83)',
#  'SW 6320 Bravado Red': '(160, 82, 78)',
#  'SW 6327 Bold Brick': '(160, 88, 79)',
#  'SW 6334 Flower Pot': '(143, 68, 56)',
#  'SW 7577 Blackberry': '(83, 54, 64)',
#  'SW 6300 Burgundy': '(99, 51, 62)',
#  'SW 6307 Fine Wine': '(114, 57, 65)',
#  'SW 6314 Luxurious Red': '(134, 58, 66)',
#  'SW 6321 Red Bay': '(142, 55, 56)',
#  'SW 6328 Fireweed': '(123, 55, 48)',
#  'SW 6335 Fired Brick': '(131, 56, 42)',
#  'SW 6022 Breathless': '(214, 194, 190)',
#  'SW 6029 White Truffle': '(215, 200, 194)',
#  'SW 6043 Unfussy Beige': '(214, 200, 192)',
#  'SW 6050 Abalone Shell': '(219, 199, 189)',
#  'SW 6057 Malted Milk': '(222, 202, 189)',
#  'SW 6064 Reticence': '(217, 205, 195)',
#  'SW 6085 Simplify Beige': '(214, 199, 185)',
#  'SW 6023 Insightful Rose': '(201, 176, 171)',
#  'SW 6030 Artistic Taupe': '(195, 177, 172)',
#  'SW 6044 Doeskin': '(198, 179, 169)',
#  'SW 6051 Sashay Sand': '(207, 180, 168)',
#  'SW 6058 Likeable Sand': '(209, 183, 168)',
#  'SW 6065 Bona Fide Beige': '(203, 185, 171)',
#  'SW 6086 Sand Dune': '(197, 177, 162)',
#  'SW 6024 Dressy Rose': '(184, 157, 154)',
#  'SW 6031 Glamour': '(182, 160, 154)',
#  'SW 6045 Emerging Taupe': '(184, 161, 150)',
#  'SW 6052 Sandbank': '(195, 164, 151)',
#  'SW 6059 Interface Tan': '(193, 163, 146)',
#  'SW 6066 Sand Trap': '(187, 165, 149)',
#  'SW 6087 Trusty Tan': '(181, 159, 143)',
#  'SW 9077 Rosaline Pearl': '(163, 136, 135)',
#  'SW 9078 Cocoa Berry': '(160, 136, 130)',
#  'SW 9079 Velvety Chestnut': '(162, 135, 125)',
#  'SW 9080 Hushed Auburn': '(168, 133, 122)',
#  'SW 9081 Redend Point': '(174, 142, 126)',
#  'SW 9082 Chocolate Powder': '(165, 140, 123)',
#  'SW 9083 Dusted Truffle': '(156, 131, 115)',
#  'SW 6025 Socialite': '(144, 118, 118)',
#  'SW 6032 Dutch Cocoa': '(140, 112, 106)',
#  'SW 6046 Swing Brown': '(148, 117, 105)',
#  'SW 6053 Reddened Earth': '(156, 110, 99)',
#  'SW 6060 Moroccan Brown': '(157, 120, 104)',
#  'SW 6067 Mocha': '(150, 122, 106)',
#  'SW 6088 Nuthatch': '(142, 114, 95)',
#  'SW 6026 River Rouge': '(118, 89, 93)',
#  'SW 6033 Bateau Brown': '(122, 95, 90)',
#  'SW 6047 Hot Cocoa': '(128, 98, 87)',
#  'SW 6054 Canyon Clay': '(133, 89, 79)',
#  'SW 6061 Tanbark': '(137, 102, 86)',
#  'SW 6068 Brevity Brown': '(113, 82, 67)',
#  'SW 6089 Grounded': '(120, 91, 71)',
#  'SW 6027 Cordovan': '(95, 61, 63)',
#  'SW 6034 Arresting Auburn': '(90, 53, 50)',
#  'SW 6048 Terra Brun': '(90, 56, 45)',
#  'SW 6055 Fiery Brown': '(93, 56, 49)',
#  'SW 6062 Rugged Brown': '(105, 67, 54)',
#  'SW 6069 French Roast': '(79, 52, 38)',
#  'SW 6090 Java': '(99, 69, 51)',
#  'SW 6869 Stop': '(195, 58, 54)',
#  'SW 6884 Obstinate Orange': '(215, 85, 42)',
#  'SW 6885 Knockout Orange': '(225, 111, 62)',
#  'SW 6886 Invigorate': '(228, 114, 55)',
#  'SW 6887 Navel': '(236, 132, 48)',
#  'SW 6892 Carnival': '(235, 136, 44)',
#  'SW 6890 Osage Orange': '(244, 160, 69)',
#  'SW 6610 Koral Kicks': '(242, 209, 195)',
#  'SW 6617 Blushing': '(240, 209, 195)',
#  'SW 6624 Peach Blossom': '(243, 208, 189)',
#  'SW 6631 Naive Peach': '(243, 211, 191)',
#  'SW 6638 Flattering Peach': '(244, 211, 179)',
#  'SW 6652 Flan': '(244, 212, 175)',
#  'SW 6659 Captivating Cream': '(244, 217, 177)',
#  'SW 6611 Jovial': '(242, 184, 167)',
#  'SW 6618 Cosmetic Peach': '(243, 193, 171)',
#  'SW 6625 Certain Peach': '(242, 189, 162)',
#  'SW 6632 Neighborly Peach': '(243, 193, 163)',
#  'SW 6639 Avid Apricot': '(244, 198, 159)',
#  'SW 6653 Delicious Melon': '(245, 200, 148)',
#  'SW 6660 Honey Blush': '(245, 207, 155)',
#  'SW 6612 Ravishing Coral': '(231, 149, 128)',
#  'SW 6619 Sockeye': '(228, 151, 128)',
#  'SW 6626 Sunset': '(226, 148, 111)',
#  'SW 6633 Inventive Orange': '(232, 157, 111)',
#  'SW 9007 Melón Meloso': '(242, 184, 140)',
#  'SW 6654 Surprise Amber': '(239, 181, 122)',
#  'SW 9008 Bellini Fizz': '(245, 199, 142)',
#  'SW 6613 Lei Flower': '(216, 123, 106)',
#  'SW 6620 Rejuvenate': '(221, 120, 97)',
#  'SW 6627 Emberglow': '(214, 124, 86)',
#  'SW 6634 Copper Harbor': '(213, 126, 82)',
#  'SW 6640 Tangerine': '(242, 172, 120)',
#  'SW 6655 Adventure Orange': '(230, 159, 95)',
#  'SW 6661 Papaya': '(239, 185, 123)',
#  'SW 6614 Quite Coral': '(199, 99, 86)',
#  'SW 6621 Emotional': '(198, 95, 71)',
#  'SW 6628 Robust Orange': '(196, 99, 62)',
#  'SW 6635 Determined Orange': '(197, 102, 57)',
#  'SW 6641 Outgoing Orange': '(230, 149, 95)',
#  'SW 6656 Serape': '(216, 139, 77)',
#  'SW 6662 Summer Day': '(234, 170, 98)',
#  'SW 6615 Peppery': '(184, 84, 68)',
#  'SW 6622 Hearty Orange': '(180, 75, 52)',
#  'SW 6629 Jalapeño': '(177, 83, 60)',
#  'SW 6636 Husky Orange': '(187, 97, 62)',
#  'SW 6642 Rhumba Orange': '(203, 120, 65)',
#  'SW 6657 Amber Wave': '(210, 130, 64)',
#  'SW 6663 Saffron Thread': '(223, 152, 78)',
#  'SW 7589 Habanero Chile': '(184, 71, 61)',
#  'SW 6881 Cayenne': '(192, 77, 53)',
#  'SW 7599 Brick Paver': '(147, 64, 47)',
#  'SW 6883 Raucous Orange': '(195, 85, 48)',
#  'SW 6643 Yam': '(195, 111, 62)',
#  'SW 7703 Earthen Jug': '(168, 94, 57)',
#  'SW 6664 Marigold': '(210, 130, 51)',
#  'SW 6337 Spun Sugar': '(237, 210, 192)',
#  'SW 6344 Peach Fuzz': '(236, 207, 187)',
#  'SW 6351 Sweet Orange': '(235, 204, 179)',
#  'SW 6358 Creamery': '(237, 208, 182)',
#  'SW 6365 Cachet Cream': '(243, 217, 186)',
#  'SW 6372 Inviting Ivory': '(242, 213, 176)',
#  'SW 6379 Jersey Cream': '(245, 222, 187)',
#  'SW 6338 Warming Peach': '(228, 185, 162)',
#  'SW 6345 Sumptuous Peach': '(229, 185, 155)',
#  'SW 6352 Soft Apricot': '(224, 179, 146)',
#  'SW 6359 Sociable': '(232, 190, 155)',
#  'SW 6366 Ambitious Amber': '(240, 203, 151)',
#  'SW 6373 Harvester': '(237, 195, 142)',
#  'SW 6380 Humble Gold': '(237, 199, 150)',
#  'SW 6339 Persimmon': '(217, 152, 124)',
#  'SW 6346 Fame Orange': '(219, 156, 123)',
#  'SW 9010 Windswept Canyon': '(219, 164, 128)',
#  'SW 9011 Sun Bleached Ochre': '(227, 171, 123)',
#  'SW 6367 Viva Gold': '(227, 172, 114)',
#  'SW 9012 Polvo de Oro': '(232, 184, 127)',
#  "SW 7682 Bee's Wax": '(234, 191, 134)',
#  'SW 9009 Subdued Sienna': '(204, 137, 108)',
#  'SW 6347 Chrysanthemum': '(196, 123, 91)',
#  'SW 6353 Chivalry Copper': '(212, 150, 110)',
#  'SW 6360 Folksy Gold': '(214, 153, 105)',
#  'SW 6368 Bakelite Gold': '(215, 153, 93)',
#  'SW 6374 Torchlight': '(229, 174, 107)',
#  'SW 6381 Anjou Pear': '(221, 172, 109)',
#  'SW 6340 Baked Clay': '(193, 120, 92)',
#  'SW 6348 Reynard': '(180, 104, 72)',
#  'SW 6354 Armagnac': '(195, 128, 88)',
#  'SW 6361 Autumnal': '(205, 140, 93)',
#  'SW 6369 Tassel': '(198, 136, 74)',
#  'SW 6375 Honeycomb': '(213, 152, 88)',
#  'SW 6382 Ceremonial Gold': '(214, 158, 89)',
#  'SW 6341 Red Cent': '(173, 101, 76)',
#  'SW 6349 Pennywise': '(162, 88, 58)',
#  'SW 6355 Truepenny': '(180, 108, 66)',
#  'SW 6362 Tigereye': '(187, 119, 72)',
#  'SW 6370 Saucy Gold': '(182, 116, 59)',
#  'SW 6376 Gold Coast': '(199, 133, 56)',
#  'SW 6383 Golden Rule': '(204, 146, 73)',
#  'SW 6342 Spicy Hue': '(153, 75, 53)',
#  'SW 7598 Sierra Redwood': '(146, 78, 60)',
#  'SW 6356 Copper Mountain': '(166, 97, 60)',
#  'SW 6363 Gingery': '(176, 108, 62)',
#  'SW 7709 Copper Pot': '(177, 106, 55)',
#  'SW 6377 Butterscotch': '(182, 125, 60)',
#  'SW 6384 Cut the Mustard': '(186, 127, 56)',
#  'SW 6078 Realist Beige': '(211, 200, 189)',
#  'SW 9085 Touch of Sand': '(213, 199, 186)',
#  'SW 6092 Lightweight Beige': '(218, 200, 184)',
#  'SW 6099 Sand Dollar': '(215, 197, 179)',
#  'SW 9094 Playa Arenosa': '(220, 199, 179)',
#  'SW 9101 Tres Naturale': '(220, 199, 173)',
#  'SW 6106 Kilim Beige': '(215, 197, 174)',
#  'SW 6079 Diverse Beige': '(194, 180, 167)',
#  'SW 9086 Cool Beige': '(198, 181, 167)',
#  'SW 6093 Familiar Beige': '(202, 179, 160)',
#  'SW 6100 Practical Beige': '(201, 178, 156)',
#  'SW 9095 Ginger Root': '(210, 183, 158)',
#  'SW 9102 Quinoa': '(207, 181, 151)',
#  'SW 6107 Nomadic Desert': '(199, 177, 152)',
#  'SW 6080 Utterly Beige': '(181, 165, 151)',
#  'SW 9087 Smoky Beige': '(185, 167, 150)',
#  'SW 6094 Sensational Sand': '(191, 163, 141)',
#  'SW 6101 Sands of Time': '(188, 163, 139)',
#  'SW 9096 Beige Intenso': '(197, 168, 141)',
#  'SW 9103 Farro': '(193, 164, 133)',
#  'SW 6108 Latte': '(186, 161, 133)',
#  'SW 9084 Cocoa Whip': '(160, 142, 126)',
#  'SW 9088 Utaupeia': '(165, 143, 123)',
#  'SW 9092 Iced Mocha': '(163, 132, 108)',
#  'SW 9093 Nearly Brown': '(168, 142, 118)',
#  'SW 9097 Soft Fawn': '(181, 151, 120)',
#  'SW 9104 Woven Wicker': '(185, 153, 116)',
#  'SW 9108 Double Latte': '(167, 140, 113)',
#  'SW 6081 Down Home': '(144, 120, 101)',
#  'SW 9089 Llama Wool': '(145, 120, 100)',
#  'SW 6095 Toasty': '(149, 114, 88)',
#  'SW 6102 Portabello': '(148, 122, 98)',
#  'SW 9098 Baked Cookie': '(137, 103, 74)',
#  'SW 9105 Almond Roca': '(167, 131, 97)',
#  'SW 6109 Hopsack': '(158, 129, 99)',
#  'SW 6082 Cobble Brown': '(122, 100, 85)',
#  'SW 9090 Caraïbe': '(120, 95, 76)',
#  'SW 6096 Jute Brown': '(129, 93, 64)',
#  'SW 6103 Tea Chest': '(125, 100, 77)',
#  'SW 9099 Saddle Up': '(114, 82, 55)',
#  'SW 9106 El Caramelo': '(148, 110, 72)',
#  'SW 6110 Steady Brown': '(138, 107, 77)',
#  'SW 6083 Sable': '(95, 75, 63)',
#  'SW 9091 Half-Caff': '(96, 76, 61)',
#  'SW 6097 Sturdy Brown': '(105, 72, 44)',
#  'SW 6104 Kaffee': '(101, 80, 61)',
#  'SW 9100 Umber Rust': '(118, 81, 56)',
#  'SW 9107 Über Umber': '(123, 88, 56)',
#  'SW 6111 Coconut Husk': '(112, 87, 63)',
#  'SW 6904 Gusto Gold': '(248, 172, 29)',
#  'SW 6905 Goldfinch': '(253, 183, 2)',
#  'SW 6902 Decisive Yellow': '(253, 204, 78)',
#  'SW 6907 Forsythia': '(255, 200, 1)',
#  'SW 6909 Lemon Twist': '(254, 217, 93)',
#  'SW 6910 Daisy': '(254, 211, 64)',
#  'SW 6911 Confident Yellow': '(254, 203, 1)',
#  'SW 6666 Enjoyable Yellow': '(245, 214, 169)',
#  'SW 6673 Banana Cream': '(245, 222, 175)',
#  'SW 9015 They call it Mellow': '(251, 228, 179)',
#  'SW 6680 Friendly Yellow': '(245, 224, 177)',
#  'SW 6687 Lantern Light': '(244, 225, 174)',
#  'SW 6694 Glad Yellow': '(245, 225, 172)',
#  'SW 1668 Pineapple Cream': '(242, 234, 195)',
#  'SW 6667 Afterglow': '(246, 205, 142)',
#  'SW 6674 Jonquil': '(247, 211, 145)',
#  'SW 9016 La Luna Amarilla': '(253, 223, 160)',
#  'SW 6681 Butter Up': '(246, 221, 163)',
#  'SW 6688 Solaria': '(245, 214, 143)',
#  'SW 6695 Midday': '(247, 215, 138)',
#  'SW 1667 Icy Lemonade': '(244, 232, 178)',
#  'SW 6668 Sunrise': '(244, 191, 119)',
#  'SW 9014 Pollen Powder': '(251, 209, 135)',
#  'SW 9017 Sunny Veranda': '(254, 223, 148)',
#  'SW 9021 Naples Yellow': '(246, 213, 143)',
#  'SW 9022 Yellow Bird': '(241, 205, 123)',
#  'SW 6696 Quilt Gold': '(234, 195, 101)',
#  'SW 1666 Venetian Yellow': '(246, 227, 161)',
#  'SW 9013 Olden Amber': '(238, 183, 107)',
#  'SW 6675 Afternoon': '(251, 203, 120)',
#  'SW 9018 Honey Bees': '(251, 214, 130)',
#  'SW 6682 June Day': '(246, 201, 115)',
#  'SW 6689 Overjoy': '(238, 194, 95)',
#  'SW 6697 Nugget': '(219, 176, 74)',
#  'SW 6908 Fun Yellow': '(247, 229, 148)',
#  'SW 6669 Yarrow': '(235, 173, 94)',
#  'SW 6676 Butterfield': '(247, 190, 91)',
#  'SW 9019 Golden Plumeria': '(251, 208, 115)',
#  'SW 6683 Bee': '(241, 186, 85)',
#  'SW 6690 Gambol Gold': '(225, 176, 71)',
#  'SW 6698 Kingdom Gold': '(209, 164, 54)',
#  'SW 6913 Funky Yellow': '(237, 210, 111)',
#  'SW 6670 Gold Crest': '(223, 153, 56)',
#  'SW 6677 Goldenrod': '(242, 175, 70)',
#  'SW 9020 Rayo de Sol': '(244, 196, 84)',
#  'SW 6684 Brittlebush': '(234, 174, 71)',
#  'SW 6691 Glitzy Gold': '(214, 160, 43)',
#  'SW 6699 Crispy Gold': '(196, 152, 50)',
#  'SW 6914 Eye Catching': '(221, 184, 53)',
#  'SW 6671 Curry': '(216, 143, 50)',
#  'SW 6678 Sunflower': '(227, 154, 51)',
#  'SW 6903 Cheerful': '(255, 199, 35)',
#  'SW 6685 Trinket': '(214, 152, 53)',
#  'SW 6692 Auric': '(196, 137, 25)',
#  'SW 7700 Olde World Gold': '(143, 108, 62)',
#  'SW 6915 Citronella': '(203, 169, 1)',
#  'SW 6386 Napery': '(239, 221, 193)',
#  'SW 6127 Ivoire': '(228, 206, 172)',
#  'SW 6120 Believable Buff': '(219, 199, 168)',
#  'SW 6393 Convivial Yellow': '(233, 214, 176)',
#  'SW 6400 Lucent Yellow': '(228, 208, 165)',
#  'SW 6407 Ancestral Gold': '(221, 205, 166)',
#  'SW 6414 Rice Paddy': '(223, 212, 176)',
#  'SW 6387 Compatible Cream': '(232, 200, 158)',
#  'SW 6128 Blonde': '(220, 189, 146)',
#  'SW 6121 Whole Wheat': '(205, 181, 146)',
#  'SW 6394 Sequin': '(225, 194, 141)',
#  'SW 9027 Pale Moss': '(220, 199, 151)',
#  'SW 6408 Wheat Grass': '(203, 181, 132)',
#  'SW 6415 Hearts of Palm': '(207, 194, 145)',
#  'SW 9023 Dakota Wheat': '(225, 189, 142)',
#  'SW 6129 Restrained Gold': '(210, 176, 132)',
#  'SW 6122 Camelback': '(197, 170, 133)',
#  'SW 9026 Tarnished Trumpet': '(213, 177, 118)',
#  'SW 6401 Independent Gold': '(210, 186, 131)',
#  'SW 9028 Dusted Olive': '(190, 167, 117)',
#  'SW 9029 Cool Avocado': '(196, 180, 125)',
#  'SW 6388 Golden Fleece': '(214, 173, 120)',
#  'SW 9024 Vintage Gold': '(203, 165, 118)',
#  'SW 9025 Coriander Powder': '(186, 156, 117)',
#  'SW 6395 Alchemy': '(201, 158, 83)',
#  'SW 6402 Antiquity': '(194, 164, 98)',
#  'SW 6409 Edgy Gold': '(177, 151, 95)',
#  'SW 6416 Sassy Green': '(187, 168, 106)',
#  'SW 6389 Butternut': '(204, 155, 92)',
#  'SW 6130 Mannered Gold': '(193, 151, 99)',
#  'SW 6123 Baguette': '(179, 145, 103)',
#  'SW 6396 Different Gold': '(188, 147, 77)',
#  'SW 6403 Escapade Gold': '(184, 155, 89)',
#  'SW 6410 Brassy': '(157, 131, 68)',
#  'SW 6417 Tupelo Tree': '(156, 145, 82)',
#  'SW 6390 Bosc Pear': '(192, 144, 86)',
#  'SW 6131 Chamois': '(173, 132, 81)',
#  'SW 6124 Cardboard': '(156, 122, 86)',
#  'SW 6397 Nankeen': '(170, 128, 58)',
#  'SW 6404 Grandiose': '(156, 127, 65)',
#  'SW 6411 Bengal Grass': '(142, 119, 63)',
#  'SW 6418 Rural Green': '(141, 132, 77)',
#  'SW 6391 Gallant Gold': '(164, 118, 60)',
#  'SW 6132 Relic Bronze': '(144, 106, 58)',
#  'SW 6125 Craft Paper': '(138, 102, 69)',
#  'SW 6398 Sconce Gold': '(153, 111, 50)',
#  'SW 6405 Fervent Brass': '(149, 121, 61)',
#  'SW 6412 Eminent Bronze': '(122, 104, 65)',
#  'SW 6419 Saguaro': '(101, 95, 45)',
#  'SW 9109 Natural Linen': '(223, 211, 195)',
#  'SW 6141 Softer Tan': '(218, 202, 178)',
#  'SW 6148 Wool Skein': '(217, 207, 186)',
#  'SW 6134 Netsuke': '(224, 207, 176)',
#  'SW 9119 Dirty Martini': '(221, 208, 182)',
#  'SW 6155 Rice Grain': '(219, 208, 185)',
#  'SW 6169 Sedate Gray': '(209, 205, 191)',
#  'SW 9110 Malabar': '(207, 190, 169)',
#  'SW 6142 Macadamia': '(204, 183, 155)',
#  'SW 6149 Relaxed Khaki': '(200, 187, 163)',
#  'SW 6135 Ecru': '(208, 186, 148)',
#  "SW 9120 Tumblin' Tumbleweed": '(205, 187, 156)',
#  'SW 6156 Ramie': '(205, 189, 162)',
#  'SW 6170 Techno Gray': '(191, 185, 170)',
#  'SW 9111 Antler Velvet': '(192, 173, 150)',
#  'SW 6143 Basket Beige': '(192, 169, 139)',
#  'SW 6150 Universal Khaki': '(184, 169, 146)',
#  'SW 6136 Harmonic Tan': '(198, 176, 138)',
#  'SW 9121 Sawgrass Basket': '(195, 176, 144)',
#  'SW 6157 Favorite Tan': '(193, 174, 145)',
#  'SW 6171 Chatroom': '(176, 171, 156)',
#  'SW 9112 Song Thrush': '(175, 152, 127)',
#  'SW 9116 Serengeti Grass': '(171, 149, 121)',
#  'SW 9117 Urban Jungle': '(164, 148, 126)',
#  'SW 9118 Tarnished Treasure': '(185, 164, 126)',
#  'SW 9122 Dried Edamame': '(177, 159, 128)',
#  'SW 7544 Fenland': '(172, 157, 131)',
#  'SW 9126 Honed Soapstone': '(157, 152, 135)',
#  'SW 9113 Mudslide': '(160, 133, 104)',
#  'SW 6144 Dapper Tan': '(148, 127, 101)',
#  'SW 6151 Quiver Tan': '(142, 127, 106)',
#  'SW 6137 Burlap': '(172, 149, 113)',
#  'SW 9123 Barro Verde': '(159, 142, 113)',
#  'SW 6158 Sawdust': '(153, 137, 112)',
#  'SW 6172 Hardware': '(139, 131, 114)',
#  'SW 9114 Fallen Leaves': '(143, 118, 89)',
#  'SW 6145 Thatch Brown': '(134, 112, 87)',
#  'SW 6152 Superior Bronze': '(120, 105, 87)',
#  'SW 6138 Artifact': '(154, 129, 94)',
#  'SW 9124 Verde Marrón': '(135, 116, 89)',
#  'SW 6159 High Tea': '(126, 111, 89)',
#  'SW 6173 Cocoon': '(114, 107, 91)',
#  'SW 9115 Cowboy Boots': '(105, 82, 57)',
#  'SW 6146 Umber': '(110, 84, 60)',
#  'SW 6153 Protégé Bronze': '(102, 84, 62)',
#  'SW 6139 Mossy Gold': '(127, 103, 67)',
#  'SW 9125 Oliva Oscuro': '(102, 84, 57)',
#  'SW 6160 Best Bronze': '(93, 81, 62)',
#  'SW 7745 Muddled Basil': '(90, 82, 67)',
#  'SW 6918 Humorous Green': '(198, 184, 54)',
#  'SW 6920 Center Stage': '(178, 194, 22)',
#  'SW 6921 Electric Lime': '(154, 186, 37)',
#  'SW 6924 Direct Green': '(63, 138, 36)',
#  'SW 6925 Envy': '(53, 140, 63)',
#  'SW 6926 Lucky Green': '(35, 134, 82)',
#  'SW 6927 Greenbelt': '(1, 114, 68)',
#  'SW 6701 Moonraker': '(238, 227, 178)',
#  'SW 6708 Springtime': '(233, 229, 179)',
#  'SW 6715 Lime Granita': '(220, 225, 184)',
#  'SW 6729 Lacewing': '(215, 227, 202)',
#  'SW 6722 Cucumber': '(211, 223, 195)',
#  'SW 6736 Jocular Green': '(204, 226, 202)',
#  'SW 6743 Mint Condition': '(209, 227, 210)',
#  'SW 6702 Lively Yellow': '(230, 216, 142)',
#  'SW 6709 Gleeful': '(218, 215, 144)',
#  'SW 6716 Dancing Green': '(197, 205, 143)',
#  'SW 6730 Romaine': '(192, 210, 173)',
#  'SW 6723 Jardin': '(189, 208, 171)',
#  'SW 6737 Kiwi': '(174, 210, 176)',
#  'SW 6744 Reclining Green': '(183, 215, 191)',
#  'SW 6703 Frolic': '(217, 198, 97)',
#  'SW 9031 Primavera': '(210, 208, 131)',
#  'SW 6717 Lime Rickey': '(175, 185, 106)',
#  'SW 9033 Oh Pistachio': '(171, 202, 153)',
#  'SW 9034 Seawashed Glass': '(169, 192, 149)',
#  'SW 6738 Vegan': '(142, 194, 152)',
#  'SW 9036 Retro Mint': '(159, 205, 177)',
#  'SW 9030 Limón Fresco': '(206, 188, 85)',
#  'SW 6710 Mélange Green': '(196, 196, 118)',
#  'SW 9032 Stay in Lime': '(159, 172, 92)',
#  'SW 6731 Picnic': '(153, 194, 133)',
#  'SW 6724 Mesclun Green': '(157, 182, 130)',
#  'SW 9035 Frosted Emerald': '(120, 177, 133)',
#  'SW 6745 Lark Green': '(138, 193, 161)',
#  'SW 6704 Hep Green': '(196, 177, 70)',
#  'SW 6711 Parakeet': '(180, 176, 90)',
#  'SW 6718 Overt Green': '(151, 165, 84)',
#  'SW 6732 Organic Green': '(127, 172, 110)',
#  'SW 6725 Pickle': '(133, 161, 106)',
#  'SW 6739 Eco Green': '(104, 166, 120)',
#  'SW 6746 Julep': '(87, 170, 128)',
#  'SW 6705 High Strung': '(172, 152, 37)',
#  'SW 6712 Luau Green': '(152, 151, 70)',
#  'SW 6719 Gecko': '(122, 136, 51)',
#  'SW 6733 Grasshopper': '(79, 133, 74)',
#  'SW 6726 Talipot Palm': '(100, 129, 73)',
#  'SW 6740 Kilkenny': '(73, 133, 85)',
#  'SW 6747 Argyle': '(52, 138, 93)',
#  'SW 6706 Offbeat Green': '(156, 139, 31)',
#  'SW 6713 Verdant': '(132, 126, 53)',
#  'SW 6720 Paradise': '(108, 123, 48)',
#  'SW 6734 Espalier': '(47, 95, 58)',
#  'SW 6727 Houseplant': '(88, 113, 63)',
#  'SW 6741 Derbyshire': '(36, 94, 54)',
#  'SW 6748 Greens': '(1, 104, 68)',
#  'SW 6421 Celery': '(224, 221, 189)',
#  'SW 6428 Honeydew': '(219, 221, 189)',
#  'SW 6435 Gratifying Green': '(218, 226, 205)',
#  'SW 6442 Supreme Green': '(207, 221, 199)',
#  'SW 6449 Topiary Tint': '(200, 216, 196)',
#  'SW 6456 Slow Green': '(198, 213, 201)',
#  'SW 6463 Breaktime': '(196, 217, 206)',
#  'SW 6422 Shagreen': '(203, 201, 157)',
#  'SW 6429 Baize Green': '(199, 205, 168)',
#  'SW 6436 Bonsai Tint': '(197, 209, 178)',
#  'SW 6443 Relish': '(179, 203, 170)',
#  'SW 6450 Easy Green': '(172, 194, 168)',
#  'SW 6457 Kind Green': '(170, 194, 179)',
#  'SW 6464 Aloe': '(172, 202, 188)',
#  'SW 9037 Baby Bok Choy': '(187, 185, 138)',
#  'SW 6430 Great Green': '(171, 180, 134)',
#  'SW 6437 Haven': '(163, 180, 140)',
#  'SW 6444 Lounge Green': '(139, 169, 127)',
#  'SW 6451 Nurture Green': '(152, 176, 146)',
#  'SW 6458 Restful': '(145, 175, 157)',
#  'SW 6465 Spearmint': '(148, 181, 166)',
#  'SW 6423 Ryegrass': '(174, 172, 122)',
#  'SW 9038 Cucuzza Verde': '(155, 163, 115)',
#  'SW 9039 Broccoflower': '(143, 162, 119)',
#  'SW 9040 Reseda Green': '(117, 148, 107)',
#  'SW 7742 Agate Green': '(142, 164, 134)',
#  'SW 9041 Parisian Patina': '(125, 155, 137)',
#  'SW 9042 Verdigreen': '(129, 165, 149)',
#  'SW 6424 Tansy Green': '(149, 148, 92)',
#  'SW 6431 Leapfrog': '(136, 145, 93)',
#  'SW 6438 Dill': '(120, 141, 96)',
#  'SW 6445 Garden Grove': '(94, 127, 87)',
#  'SW 6452 Inland': '(108, 136, 103)',
#  'SW 6459 Jadite': '(97, 130, 108)',
#  'SW 6466 Grandview': '(107, 146, 127)',
#  'SW 6425 Relentless Olive': '(113, 113, 62)',
#  'SW 6432 Garden Spot': '(109, 118, 69)',
#  'SW 6439 Greenfield': '(96, 114, 79)',
#  'SW 6446 Arugula': '(66, 96, 60)',
#  'SW 6453 Cilantro': '(83, 113, 80)',
#  'SW 6460 Kale Green': '(79, 106, 86)',
#  'SW 6467 Kendal Green': '(84, 120, 103)',
#  'SW 6426 Basque Green': '(95, 96, 51)',
#  'SW 6433 Inverness': '(87, 98, 56)',
#  'SW 6440 Courtyard': '(71, 88, 66)',
#  'SW 6447 Evergreens': '(64, 88, 64)',
#  'SW 6454 Shamrock': '(32, 81, 52)',
#  'SW 6461 Isle of Pines': '(61, 85, 65)',
#  'SW 6468 Hunt Club': '(42, 79, 67)',
#  'SW 6162 Ancient Marble': '(209, 204, 185)',
#  'SW 6176 Liveable Green': '(206, 206, 189)',
#  'SW 6190 Filmy Green': '(209, 211, 199)',
#  'SW 6183 Conservative Gray': '(209, 208, 198)',
#  'SW 6197 Aloof Gray': '(201, 201, 192)',
#  'SW 6204 Sea Salt': '(205, 210, 202)',
#  'SW 6211 Rainwashed': '(194, 205, 197)',
#  'SW 6163 Grassland': '(193, 188, 167)',
#  'SW 6177 Softened Green': '(187, 188, 167)',
#  'SW 6191 Contented': '(189, 192, 179)',
#  'SW 6184 Austere Gray': '(190, 191, 178)',
#  'SW 6198 Sensible Hue': '(182, 181, 171)',
#  'SW 6205 Comfort Gray': '(190, 195, 187)',
#  'SW 6212 Quietude': '(173, 187, 178)',
#  'SW 6164 Svelte Sage': '(178, 172, 150)',
#  'SW 6178 Clary Sage': '(172, 173, 151)',
#  'SW 6192 Coastal Plain': '(159, 166, 148)',
#  'SW 6185 Escape Gray': '(171, 172, 159)',
#  'SW 6199 Rare Gray': '(166, 166, 155)',
#  'SW 6206 Oyster Bay': '(174, 179, 169)',
#  'SW 6213 Halcyon Green': '(155, 170, 162)',
#  'SW 9127 At Ease Soldier': '(158, 153, 133)',
#  'SW 9128 Green Onyx': '(152, 154, 130)',
#  'SW 9129 Jade Dragon': '(144, 152, 134)',
#  'SW 9130 Evergreen Fog': '(149, 151, 138)',
#  'SW 9131 Cornwall Slate': '(148, 148, 136)',
#  'SW 9132 Acacia Haze': '(150, 156, 146)',
#  'SW 9133 Jasper Stone': '(141, 158, 151)',
#  'SW 6165 Connected Gray': '(137, 132, 115)',
#  'SW 6179 Artichoke': '(127, 130, 102)',
#  'SW 6193 Privilege Green': '(122, 135, 117)',
#  'SW 6186 Dried Thyme': '(123, 128, 112)',
#  'SW 6200 Link Gray': '(127, 126, 114)',
#  'SW 6207 Retreat': '(122, 128, 118)',
#  'SW 6214 Underseas': '(124, 142, 135)',
#  'SW 6166 Eclipse': '(107, 103, 87)',
#  'SW 6180 Oakmoss': '(101, 104, 76)',
#  'SW 6194 Basil': '(98, 110, 96)',
#  'SW 6187 Rosemary': '(100, 105, 92)',
#  'SW 6201 Thunderous': '(109, 108, 98)',
#  'SW 6208 Pewter Green': '(94, 98, 89)',
#  'SW 6215 Rocky River': '(94, 112, 106)',
#  'SW 6167 Garden Gate': '(94, 89, 73)',
#  'SW 6181 Secret Garden': '(79, 82, 58)',
#  'SW 6195 Rock Garden': '(70, 84, 72)',
#  'SW 6188 Shade-Grown': '(78, 81, 71)',
#  'SW 6202 Cast Iron': '(100, 100, 90)',
#  'SW 6209 Ripe Olive': '(68, 72, 61)',
#  'SW 6216 Jasper': '(52, 59, 54)',
#  'SW 6987 Jitterbug Jade': '(1, 157, 110)',
#  'SW 6941 Nifty Turquoise': '(1, 145, 135)',
#  'SW 6942 Splashy': '(1, 145, 150)',
#  'SW 6943 Intense Teal': '(1, 118, 128)',
#  'SW 6950 Calypso': '(1, 176, 187)',
#  'SW 6958 Dynamic Blue': '(1, 146, 198)',
#  'SW 6965 Hyper Blue': '(1, 95, 151)',
#  'SW 6750 Waterfall': '(192, 227, 218)',
#  'SW 6757 Tame Teal': '(193, 230, 223)',
#  'SW 6764 Swimming': '(194, 229, 229)',
#  'SW 6771 Bathe Blue': '(194, 224, 227)',
#  'SW 6778 Aviary Blue': '(198, 227, 232)',
#  'SW 6785 Quench Blue': '(180, 224, 231)',
#  'SW 6792 Minor Blue': '(183, 223, 232)',
#  'SW 6751 Refresh': '(161, 212, 200)',
#  'SW 6758 Aqueduct': '(161, 213, 203)',
#  'SW 6765 Spa': '(167, 220, 220)',
#  'SW 6772 Cay': '(166, 208, 214)',
#  'SW 6779 Liquid Blue': '(166, 212, 222)',
#  'SW 6786 Cloudless': '(143, 208, 221)',
#  'SW 6793 Bluebell': '(162, 213, 231)',
#  'SW 9043 Aquastone': '(137, 198, 183)',
#  'SW 9044 Little Blue Box': '(138, 197, 186)',
#  'SW 9045 Bora Bora Shore': '(146, 208, 208)',
#  'SW 9046 Gentle Aquamarine': '(151, 203, 210)',
#  'SW 9047 After the Rain': '(139, 196, 209)',
#  "SW 9048 Surfin'": '(115, 192, 210)',
#  'SW 9049 Sky Fall': '(137, 198, 223)',
#  'SW 6752 Larchmere': '(112, 186, 167)',
#  'SW 6759 Cooled Blue': '(117, 185, 174)',
#  'SW 6766 Mariner': '(110, 194, 196)',
#  'SW 6773 Rapture Blue': '(125, 193, 203)',
#  'SW 6780 Nautilus': '(113, 184, 199)',
#  'SW 6787 Fountain': '(86, 181, 202)',
#  'SW 6794 Flyway': '(93, 179, 212)',
#  'SW 6753 Jargon Jade': '(83, 163, 143)',
#  'SW 6760 Rivulet': '(97, 168, 157)',
#  'SW 6767 Aquarium': '(58, 169, 174)',
#  'SW 6774 Freshwater': '(77, 166, 178)',
#  'SW 6781 Jamaica Bay': '(52, 163, 182)',
#  'SW 6788 Capri': '(1, 160, 184)',
#  'SW 6795 Major Blue': '(40, 158, 196)',
#  'SW 6754 Ionian': '(54, 137, 118)',
#  'SW 6761 Thermal Spring': '(59, 140, 128)',
#  'SW 6768 Gulfstream': '(1, 133, 139)',
#  'SW 6775 Briny': '(8, 128, 142)',
#  'SW 6782 Cruising': '(1, 132, 152)',
#  'SW 6789 Blue Mosque': '(1, 129, 158)',
#  'SW 6796 Blue Plate': '(1, 124, 167)',
#  'SW 6755 Starboard': '(1, 108, 79)',
#  'SW 6762 Poseidon': '(1, 109, 96)',
#  'SW 6769 Maxi Teal': '(1, 116, 120)',
#  'SW 6776 Blue Nile': '(1, 113, 126)',
#  'SW 6783 Amalfi': '(1, 110, 133)',
#  'SW 6790 Adriatic Sea': '(1, 96, 129)',
#  'SW 6797 Jay Blue': '(1, 93, 135)',
#  'SW 6470 Waterscape': '(191, 210, 201)',
#  'SW 6477 Tidewater': '(195, 215, 211)',
#  'SW 6484 Meander Blue': '(190, 219, 216)',
#  'SW 6491 Open Air': '(199, 223, 224)',
#  'SW 9054 Little Boy Blu': '(199, 216, 219)',
#  'SW 6498 Byte Blue': '(197, 220, 224)',
#  'SW 6505 Atmospheric': '(194, 218, 224)',
#  'SW 6471 Hazel': '(168, 193, 183)',
#  'SW 6478 Watery': '(180, 204, 201)',
#  'SW 6485 Raindrop': '(158, 198, 198)',
#  'SW 6492 Jetstream': '(176, 210, 214)',
#  'SW 9055 Billowy Breeze': '(175, 199, 205)',
#  'SW 6499 Stream': '(173, 204, 211)',
#  'SW 6506 Vast Sky': '(169, 201, 215)',
#  'SW 9050 Vintage Vessel': '(148, 178, 166)',
#  'SW 9051 Aquaverde': '(163, 192, 189)',
#  'SW 9052 Blithe Blue': '(144, 189, 189)',
#  'SW 9053 Agua Fría': '(159, 197, 204)',
#  'SW 9056 French Moire': '(159, 187, 195)',
#  'SW 9061 Rest Assured': '(155, 191, 201)',
#  'SW 6507 Resolute Blue': '(133, 176, 196)',
#  'SW 6472 Composed': '(126, 162, 152)',
#  'SW 6479 Drizzle': '(140, 174, 171)',
#  'SW 6486 Reflecting Pool': '(123, 177, 178)',
#  'SW 6493 Ebbtide': '(132, 180, 190)',
#  'SW 9057 Aquitaine': '(136, 171, 180)',
#  'SW 6500 Open Seas': '(131, 175, 188)',
#  'SW 9062 Bluebird Feather': '(111, 157, 179)',
#  'SW 6473 Surf Green': '(95, 136, 125)',
#  'SW 6480 Lagoon': '(81, 134, 130)',
#  'SW 6487 Cloudburst': '(92, 149, 152)',
#  'SW 6494 Lakeshore': '(91, 150, 162)',
#  'SW 9058 Secret Cove': '(104, 144, 157)',
#  'SW 6501 Manitou Blue': '(91, 146, 162)',
#  'SW 6508 Secure Blue': '(83, 137, 161)',
#  'SW 6474 Raging Sea': '(71, 111, 101)',
#  'SW 6481 Green Bay': '(46, 104, 100)',
#  'SW 6488 Grand Canal': '(60, 121, 125)',
#  'SW 6495 Great Falls': '(33, 119, 134)',
#  'SW 9059 Silken Peacock': '(66, 117, 132)',
#  'SW 6502 Loch Blue': '(47, 119, 139)',
#  'SW 6509 Georgian Bay': '(34, 101, 127)',
#  'SW 6475 Country Squire': '(18, 74, 66)',
#  'SW 6482 Cape Verde': '(1, 85, 79)',
#  'SW 6489 Really Teal': '(1, 99, 103)',
#  'SW 6496 Oceanside': '(1, 90, 107)',
#  "SW 9060 Connor's Lakefront": '(23, 90, 108)',
#  'SW 6503 Bosporus': '(1, 93, 117)',
#  'SW 6510 Loyal Blue': '(1, 69, 94)',
#  'SW 6218 Tradewind': '(194, 207, 207)',
#  'SW 6225 Sleepy Blue': '(188, 203, 206)',
#  'SW 9136 Lullaby': '(203, 212, 212)',
#  'SW 6232 Misty': '(205, 210, 210)',
#  'SW 9144 Moonmist': '(201, 217, 224)',
#  'SW 6239 Upward': '(191, 201, 208)',
#  'SW 6246 North Star': '(202, 208, 210)',
#  'SW 6219 Rain': '(171, 190, 191)',
#  'SW 6226 Languid Blue': '(164, 183, 189)',
#  'SW 9137 Niebla Azul': '(182, 195, 196)',
#  'SW 6233 Samovar Silver': '(184, 190, 190)',
#  'SW 9145 Sleepy Hollow': '(183, 201, 209)',
#  'SW 6240 Windy Blue': '(170, 186, 198)',
#  'SW 6247 Krypton': '(184, 192, 195)',
#  'SW 6220 Interesting Aqua': '(155, 175, 178)',
#  'SW 6227 Meditative': '(150, 170, 176)',
#  'SW 9138 Stardew': '(166, 178, 181)',
#  'SW 6234 Uncertain Gray': '(169, 176, 177)',
#  'SW 9146 Faded Flaxflower': '(158, 180, 192)',
#  'SW 6241 Aleutian': '(152, 169, 183)',
#  'SW 6248 Jubilee': '(173, 181, 185)',
#  'SW 9134 Delft': '(139, 159, 160)',
#  'SW 9135 Whirlpool': '(128, 150, 157)',
#  'SW 9139 Debonair': '(144, 160, 166)',
#  'SW 9143 Cadet': '(145, 153, 156)',
#  'SW 9147 Favorite Jeans': '(138, 163, 177)',
#  'SW 9151 Daphne': '(137, 156, 170)',
#  'SW 9152 Let it Rain': '(151, 159, 165)',
#  'SW 6221 Moody Blue': '(122, 145, 146)',
#  'SW 6228 Refuge': '(96, 125, 132)',
#  'SW 9140 Blustery Sky': '(111, 132, 140)',
#  'SW 6235 Foggy Day': '(114, 124, 127)',
#  'SW 9148 Smoky Azurite': '(112, 141, 158)',
#  'SW 6242 Bracing Blue': '(118, 139, 154)',
#  'SW 6249 Storm Cloud': '(122, 132, 141)',
#  'SW 6222 Riverway': '(93, 114, 116)',
#  'SW 6229 Tempe Star': '(71, 98, 106)',
#  'SW 9141 Waterloo': '(83, 104, 114)',
#  'SW 6236 Grays Harbor': '(89, 99, 104)',
#  'SW 9149 Inky Blue': '(78, 114, 135)',
#  'SW 6243 Distance': '(93, 111, 127)',
#  'SW 6250 Granite Peak': '(96, 107, 117)',
#  'SW 6223 Still Water': '(74, 93, 95)',
#  'SW 6230 Rainstorm': '(36, 70, 83)',
#  'SW 9142 Moscow Midnight': '(32, 70, 82)',
#  'SW 6237 Dark Night': '(35, 56, 63)',
#  'SW 9150 Endless Sea': '(50, 88, 110)',
#  'SW 7602 Indigo Batik': '(62, 80, 99)',
#  'SW 6251 Outerspace': '(88, 97, 104)',
#  'SW 6959 Blue Chip': '(1, 110, 167)',
#  'SW 6966 Blueblood': '(1, 80, 134)',
#  'SW 6967 Frank Blue': '(34, 82, 136)',
#  'SW 6971 Morning Glory': '(60, 76, 128)',
#  'SW 6983 Fully Purple': '(81, 76, 126)',
#  'SW 6982 African Violet': '(102, 83, 133)',
#  'SW 6981 Passionate Purple': '(121, 84, 132)',
#  'SW 6799 Soar': '(195, 223, 232)',
#  'SW 6526 Icelandic': '(203, 216, 225)',
#  'SW 6806 Rhythmic Blue': '(204, 219, 229)',
#  'SW 6813 Wishful Blue': '(216, 221, 230)',
#  'SW 6820 Inspired Lilac': '(223, 217, 228)',
#  'SW 6827 Elation': '(223, 220, 229)',
#  'SW 6834 Spangle': '(229, 219, 229)',
#  'SW 6800 Something Blue': '(176, 214, 230)',
#  'SW 6527 Blissful Blue': '(178, 200, 216)',
#  'SW 6807 Wondrous Blue': '(184, 205, 221)',
#  'SW 6814 Breathtaking': '(199, 209, 226)',
#  'SW 6821 Potentially Purple': '(209, 203, 223)',
#  'SW 6828 Rhapsody Lilac': '(210, 200, 221)',
#  'SW 6835 Euphoric Lilac': '(218, 199, 218)',
#  'SW 9063 Porch Ceiling': '(155, 200, 222)',
#  'SW 6528 Cosmos': '(142, 169, 194)',
#  'SW 6808 Celestial': '(151, 179, 208)',
#  'SW 9066 Agapanthus': '(187, 197, 222)',
#  'SW 6822 Wisteria': '(189, 180, 212)',
#  'SW 6829 Magical': '(192, 175, 208)',
#  'SW 6836 Novel Lilac': '(194, 164, 194)',
#  'SW 6801 Regale Blue': '(125, 181, 211)',
#  'SW 9064 Bluesy Note': '(124, 154, 181)',
#  'SW 6809 Lobelia': '(116, 152, 190)',
#  'SW 6815 Awesome Violet': '(167, 178, 212)',
#  'SW 9067 Forever Lilac': '(175, 165, 199)',
#  'SW 9068 Berry Frappé': '(179, 161, 198)',
#  'SW 6837 Baroness': '(167, 133, 167)',
#  'SW 6802 Jacaranda': '(90, 158, 192)',
#  'SW 6529 Scanda': '(107, 140, 169)',
#  'SW 9065 Perfect Periwinkle': '(100, 135, 176)',
#  'SW 6816 Dahlia': '(139, 152, 196)',
#  'SW 6823 Brave Purple': '(150, 141, 184)',
#  'SW 6830 Kismet': '(161, 138, 183)',
#  'SW 9069 Veri Berri': '(147, 116, 150)',
#  'SW 6803 Danube': '(35, 119, 162)',
#  'SW 6530 Revel Blue': '(76, 107, 138)',
#  'SW 6810 Lupine': '(78, 115, 159)',
#  'SW 6817 Gentian': '(101, 114, 165)',
#  'SW 6824 Forget-Me-Not': '(113, 105, 152)',
#  'SW 6831 Clematis': '(126, 101, 150)',
#  'SW 6838 Vigorous Violet': '(124, 90, 126)',
#  'SW 6804 Dignity Blue': '(9, 76, 115)',
#  'SW 6531 Indigo': '(40, 74, 112)',
#  'SW 6811 Honorable Blue': '(22, 69, 118)',
#  'SW 6818 Valiant Violet': '(62, 67, 113)',
#  'SW 6825 Izmir Purple': '(77, 66, 110)',
#  'SW 6832 Impulsive Purple': '(98, 73, 119)',
#  'SW 6839 Kimono Violet': '(93, 57, 95)',
#  'SW 6512 Balmy': '(197, 216, 222)',
#  'SW 6519 Hinting Blue': '(206, 217, 221)',
#  'SW 6533 Mild Blue': '(203, 213, 219)',
#  'SW 6540 Starry Night': '(214, 217, 222)',
#  'SW 6547 Silver Peony': '(218, 214, 219)',
#  'SW 6554 Lite Lavender': '(224, 218, 223)',
#  'SW 6281 Wallflower': '(219, 207, 212)',
#  'SW 6513 Take Five': '(179, 201, 211)',
#  'SW 6520 Honest Blue': '(178, 199, 211)',
#  'SW 6534 Icy': '(187, 199, 210)',
#  'SW 6541 Daydream': '(189, 195, 205)',
#  'SW 6548 Grape Mist': '(197, 192, 201)',
#  'SW 6555 Enchant': '(209, 198, 210)',
#  'SW 6282 Mauve Finery': '(203, 184, 192)',
#  'SW 6514 Respite': '(151, 180, 195)',
#  'SW 6521 Notable Hue': '(139, 167, 187)',
#  'SW 6535 Solitude': '(153, 167, 184)',
#  'SW 6542 Vesper Violet': '(153, 160, 178)',
#  'SW 6549 Ash Violet': '(162, 155, 170)',
#  'SW 6556 Obi Lilac': '(176, 163, 182)',
#  'SW 6283 Thistle': '(170, 142, 154)',
#  'SW 9070 Baby Blue Eyes': '(131, 162, 180)',
#  "SW 9071 Dyer's Woad": '(123, 153, 176)',
#  'SW 9072 Dried Lavender': '(133, 149, 170)',
#  'SW 9073 Dusty Heather': '(137, 144, 163)',
#  'SW 9074 Gentle Grape': '(144, 138, 155)',
#  'SW 9075 Berry Cream': '(154, 140, 162)',
#  'SW 9076 Ruby Violet': '(155, 126, 139)',
#  'SW 6515 Leisure Blue': '(106, 142, 161)',
#  'SW 6522 Sporty Blue': '(106, 138, 164)',
#  'SW 6536 Searching Blue': '(108, 127, 154)',
#  'SW 6543 Soulful Blue': '(117, 124, 145)',
#  'SW 6550 Mythical': '(126, 119, 142)',
#  'SW 6557 Wood Violet': '(122, 107, 133)',
#  'SW 6284 Plum Dandy': '(139, 104, 120)',
#  'SW 6516 Down Pour': '(67, 113, 139)',
#  'SW 6523 Denim': '(80, 107, 132)',
#  'SW 6537 Luxe Blue': '(81, 101, 130)',
#  'SW 6544 Mesmerize': '(93, 101, 123)',
#  'SW 6551 Purple Passage': '(100, 94, 119)',
#  'SW 6558 Plummy': '(103, 90, 117)',
#  'SW 6285 Grape Harvest': '(126, 90, 109)',
#  'SW 6517 Regatta': '(33, 87, 114)',
#  'SW 6524 Commodore': '(37, 71, 106)',
#  'SW 6538 Dignified': '(59, 73, 109)',
#  'SW 6545 Majestic Purple': '(59, 60, 90)',
#  'SW 6552 Dewberry': '(62, 56, 90)',
#  'SW 6559 Concord Grape': '(68, 55, 87)',
#  'SW 6286 Mature Grape': '(95, 63, 84)',
#  'SW 6274 Destiny': '(207, 201, 200)',
#  'SW 7078 Minute Mauve': '(207, 201, 200)',
#  'SW 6260 Unique Gray': '(203, 201, 201)',
#  'SW 6267 Sensitive Tint': '(206, 201, 204)',
#  'SW 6015 Vaguely Mauve': '(209, 197, 196)',
#  'SW 6008 Individual White': '(212, 205, 202)',
#  'SW 6036 Angora': '(209, 197, 190)',
#  'SW 6275 Fashionable Gray': '(189, 184, 184)',
#  'SW 7079 Ponder': '(188, 182, 182)',
#  'SW 6261 Swanky Gray': '(181, 177, 181)',
#  'SW 6268 Veiled Violet': '(189, 181, 185)',
#  'SW 6016 Chaise Mauve': '(193, 178, 179)',
#  'SW 6009 Imagine': '(194, 182, 182)',
#  'SW 6037 Temperate Taupe': '(191, 177, 170)',
#  'SW 6276 Mystical Shade': '(174, 169, 170)',
#  'SW 7080 Quest Gray': '(173, 165, 165)',
#  'SW 6262 Mysterious Mauve': '(166, 163, 169)',
#  'SW 6269 Beguiling Mauve': '(175, 167, 172)',
#  'SW 6017 Intuitive': '(179, 163, 165)',
#  'SW 6010 Flexible Gray': '(177, 163, 161)',
#  'SW 6038 Truly Taupe': '(172, 158, 151)',
#  'SW 9153 Moonlit Orchid': '(148, 145, 148)',
#  'SW 9155 Slate Violet': '(152, 145, 146)',
#  'SW 9156 Gris Morado': '(143, 138, 145)',
#  'SW 9157 Autumn Orchid': '(157, 144, 147)',
#  'SW 9158 Coquina': '(157, 141, 142)',
#  'SW 9159 Auger Shell': '(159, 146, 145)',
#  'SW 9160 Armadillo': '(158, 144, 137)',
#  'SW 6277 Special Gray': '(123, 120, 125)',
#  'SW 7081 Sensuous Gray': '(131, 125, 127)',
#  'SW 6263 Exclusive Plum': '(115, 111, 120)',
#  'SW 6270 Soulmate': '(133, 119, 123)',
#  'SW 6018 Enigma': '(139, 124, 126)',
#  'SW 6011 Chinchilla': '(134, 120, 117)',
#  'SW 6039 Poised Taupe': '(140, 126, 120)',
#  'SW 6278 Cloak Gray': '(96, 94, 99)',
#  'SW 7082 Stunning Shade': '(103, 96, 100)',
#  'SW 6264 Midnight': '(93, 89, 98)',
#  'SW 6271 Expressive Plum': '(105, 92, 98)',
#  'SW 6019 Poetry Plum': '(111, 92, 95)',
#  'SW 6012 Browse Brown': '(110, 97, 95)',
#  'SW 6040 Less Brown': '(117, 103, 97)',
#  'SW 9154 Perle Noir': '(79, 77, 81)',
#  'SW 7083 Darkroom': '(68, 62, 64)',
#  'SW 6265 Quixotic Plum': '(74, 70, 83)',
#  'SW 6272 Plum Brown': '(78, 66, 71)',
#  'SW 6020 Marooned': '(78, 49, 50)',
#  'SW 6013 Bitter Chocolate': '(77, 60, 60)',
#  'SW 6041 Otter': '(86, 67, 59)',
#  'SW 7023 Requisite Gray': '(185, 178, 169)',
#  'SW 6072 Versatile Gray': '(193, 182, 171)',
#  'SW 7016 Mindful Gray': '(188, 183, 173)',
#  'SW 7044 Amazing Gray': '(190, 181, 169)',
#  'SW 7638 Jogging Path': '(192, 185, 169)',
#  'SW 7506 Loggia': '(196, 183, 165)',
#  'SW 7037 Balanced Beige': '(192, 178, 162)',
#  'SW 7661 Reflection': '(211, 213, 211)',
#  'SW 6253 Olympus White': '(212, 216, 215)',
#  'SW 7071 Gray Screen': '(198, 202, 202)',
#  'SW 7064 Passive': '(203, 204, 201)',
#  'SW 7057 Silver Strand': '(200, 203, 196)',
#  'SW 9165 Gossamer Veil': '(211, 206, 196)',
#  'SW 7653 Silverpointe': '(209, 210, 203)',
#  'SW 7662 Evening Shadow': '(201, 204, 205)',
#  'SW 6254 Lazy Gray': '(190, 193, 195)',
#  'SW 7072 Online': '(176, 181, 181)',
#  'SW 7065 Argos': '(189, 189, 183)',
#  'SW 7058 Magnetic Gray': '(178, 181, 175)',
#  'SW 9166 Drift of Mist': '(220, 216, 208)',
#  'SW 7654 Lattice': '(206, 206, 198)',
#  'SW 7663 Monorail Silver': '(184, 188, 187)',
#  'SW 6255 Morning Fog': '(168, 174, 177)',
#  'SW 7073 Network Gray': '(160, 165, 167)',
#  'SW 7066 Gray Matters': '(167, 168, 162)',
#  'SW 7059 Unusual Gray': '(163, 167, 160)',
#  'SW 7658 Gray Clouds': '(183, 183, 178)',
#  'SW 7651 Front Porch': '(204, 204, 197)',
#  'SW 7664 Steely Gray': '(144, 151, 155)',
#  'SW 9161 Dustblu': '(149, 155, 160)',
#  'SW 9162 African Gray': '(147, 152, 153)',
#  'SW 9163 Tin Lizzie': '(147, 149, 145)',
#  'SW 9164 Illusive Green': '(146, 148, 141)',
#  'SW 7652 Mineral Deposit': '(171, 176, 172)',
#  'SW 7657 Tinsmith': '(197, 200, 196)',
#  'SW 7665 Wall Street': '(101, 109, 115)',
#  'SW 6256 Serious Gray': '(125, 132, 139)',
#  'SW 7074 Software': '(127, 132, 134)',
#  'SW 7067 Cityscape': '(127, 129, 126)',
#  'SW 7060 Attitude Gray': '(124, 125, 117)',
#  'SW 7659 Gris': '(165, 169, 168)',
#  'SW 7649 Silverplate': '(194, 192, 186)',
#  'SW 7624 Slate Tile': '(96, 110, 116)',
#  'SW 6257 Gibraltar': '(98, 105, 112)',
#  'SW 7075 Web Gray': '(97, 102, 105)',
#  'SW 7068 Grizzle Gray': '(99, 101, 98)',
#  'SW 7061 Night Owl': '(99, 101, 95)',
#  'SW 7660 Earl Grey': '(150, 154, 150)',
#  'SW 7650 Ellie Gray': '(170, 169, 164)',
#  'SW 7604 Smoky Blue': '(89, 110, 121)',
#  'SW 7615 Sea Serpent': '(62, 75, 84)',
#  'SW 7076 Cyberspace': '(68, 72, 77)',
#  'SW 7674 Peppercorn': '(88, 88, 88)',
#  'SW 7749 Laurel Woods': '(68, 73, 61)',
#  'SW 7622 Homburg Gray': '(102, 109, 105)',
#  'SW 7655 Stamped Concrete': '(160, 160, 154)',
#  'SW 6001 Grayish': '(207, 202, 199)',
#  'SW 7022 Alpaca': '(204, 197, 189)',
#  'SW 6071 Popular Gray': '(212, 204, 195)',
#  'SW 7029 Agreeable Gray': '(209, 203, 193)',
#  'SW 7015 Repose Gray': '(204, 201, 192)',
#  'SW 7043 Worldly Gray': '(206, 198, 187)',
#  'SW 7050 Useful Gray': '(207, 202, 189)',
#  'SW 6002 Essential Gray': '(188, 184, 182)',
#  'SW 7030 Anew Gray': '(191, 182, 170)',
#  'SW 7051 Analytical Gray': '(191, 182, 167)',
#  'SW 6003 Proper Gray': '(173, 168, 165)',
#  'SW 7024 Functional Gray': '(171, 163, 154)',
#  'SW 6073 Perfect Greige': '(183, 171, 159)',
#  'SW 7031 Mega Greige': '(173, 162, 149)',
#  'SW 7017 Dorian Gray': '(172, 167, 158)',
#  'SW 7045 Intellectual Gray': '(168, 160, 147)',
#  'SW 7052 Gray Area': '(175, 166, 150)',
#  'SW 9167 Polished Concrete': '(158, 151, 147)',
#  'SW 9168 Elephant Ear': '(152, 143, 133)',
#  'SW 9169 Chatura Gray': '(160, 146, 135)',
#  ...}

# %% [markdown]
# ## Cleaning Up
#
# As you can see the colors have the Sherwin-Williams initials (SW) and a number that prefixes their name. Also, we want to convert the RGBs to hexadecimal for convenience.

# %%
def rgb_to_hex(rgb):
  r, g, b = [int(_) for _ in rgb]
  return (
    "#" + 
    f'0{hex(r)[2:]}'[-2:] + 
    f'0{hex(g)[2:]}'[-2:] + 
    f'0{hex(b)[2:]}'[-2:]
  )

# %%
# clean the color names:
clean_colors = {
    re.sub(r'^SW[\d\s]+', r'', color_name):
      # remove parentheses and cast to array:
      rgb_to_hex(color_value[1:-1].split(','))

    for color_name, color_value in colors.items()
}

# %%
clean_colors

# %% [markdown]
# ## Convert to CSV for portability

# %%
with open('sherwin-williams.csv', 'w') as f:
  f.write(f'name,hex\n')
  for name, hexcode in clean_colors.items():
    f.write(f'{name},{hexcode}\n')

# %% [markdown]
# ## Mining Color Names and their Hex-Codes
#
# Using BeautifulSoup!

# %%
import re
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Extract HTML Code
#
# By navigating to the page with Selenium, the Javascript is executed and we can retrieve the generated HTML with `execute_script`, which executes our Javascript code.

# %%
colornames = requests.get('http://mkweb.bcgsc.ca/colornames/').content

# initialize BS to run on color_wall_webpage_html:
soup = BeautifulSoup(colornames, 'html.parser')

# %% [markdown]
# ## Mining Color Patches with BeautifulSoup
#
# Luckily, all patches are tagged with `class="patch"`, however, the color name is in the parent `div`, with class `swatch`.

# %%
# take only swatches with one children (they contain the colors):
color_swatches = filter(
    lambda s: len(s.findChildren()) == 1,
    soup.find_all('div', class_='swatch')
)

colors = {}
for swatch in color_swatches:
  # remove the child text from the parent:
  child = swatch.findChildren()[0]
  color_name = swatch.text[len(child.text):]
  # get the color hex-code from the child:
  color_code = swatch.findChildren()[0].get('style')
  
  if not color_code:
    continue

  colors[color_name] = color_code

# %%
colors
# Out:
# {'beer srm 01 rgb=254,231,153 #FEE799 lch=92,41,94 vis[8881][249,228,150](1.0)': 'background:#FEE799;',
#  'beer srm 02 rgb=253,217,121 #FDD979 lch=88,51,89 la_luna[4899][255,216,122](1.0)': 'background:#FDD979;',
#  'beer srm 03 rgb=253,203,90 #FDCB5A lch=84,62,84 golden_tainoi[3927][255,204,92](1.0)': 'background:#FDCB5A;',
#  'beer srm 04 rgb=252,193,67 #FCC143 lch=81,69,82 PMS136[47][252,191,73](3.2)': 'background:#FCC143;',
#  'beer srm 05 rgb=247,179,36 #F7B324 lch=77,76,80 filmpro_golden_yellow[3612][247,181,45](2.4)': 'background:#F7B324;',
#  'beer srm 06 rgb=246,168,3 #F6A803 lch=75,80,77 sun[8121][251,172,19](1.4)': 'background:#F6A803;',
#  'beer srm 07 rgb=238,158,3 #EE9E03 lch=71,78,75 orange[6199][238,154,0](3.2)': 'background:#EE9E03;',
#  'beer srm 08 rgb=230,146,3 #E69203 lch=68,76,72 PMS130_2X[39][226,145,0](1.4)': 'background:#E69203;',
#  'beer srm 09 rgb=227,138,4 #E38A04 lch=65,75,69 PMS144[60][226,140,5](1.7)': 'background:#E38A04;',
#  'beer srm 10 rgb=217,126,3 #D97E03 lch=61,73,67 yellow_ochre[9215][227,130,23](3.7)': 'background:#D97E03;',
#  'beer srm 11 rgb=211,116,0 #D37400 lch=58,73,64 PMS717[896][211,109,0](4.2)': 'background:#D37400;',
#  'beer srm 12 rgb=202,108,0 #CA6C00 lch=55,71,63 browny_orange[1872][202,107,2](0.0)': 'background:#CA6C00;',
#  'beer srm 13 rgb=198,100,1 #C66401 lch=53,70,61 PMS159[85][198,96,5](2.4)': 'background:#C66401;',
#  'beer srm 14 rgb=191,92,1 #BF5C01 lch=50,69,59 PMS718[897][191,91,0](0.0)': 'background:#BF5C01;',
#  'beer srm 15 rgb=181,83,0 #B55300 lch=47,67,57 PMS1525[72][181,84,0](0.0)': 'background:#B55300;',
#  'beer srm 16 rgb=176,79,0 #B04F00 lch=45,66,57 cinnamon[2336][172,79,6](2.2)': 'background:#B04F00;',
#  'beer srm 17 rgb=171,71,3 #AB4703 lch=43,65,54 fire[3635][170,66,3](2.4)': 'background:#AB4703;',
#  'beer srm 18 rgb=162,64,3 #A24003 lch=40,63,53 PMS471_2X[575][163,68,2](1.7)': 'background:#A24003;',
#  'beer srm 19 rgb=156,57,3 #9C3903 lch=38,62,51 russet[7375][161,57,5](2.2)': 'background:#9C3903;',
#  'beer srm 20 rgb=150,53,3 #963503 lch=36,61,50 russet[7375][161,57,5](3.7)': 'background:#963503;',
#  'beer srm 21 rgb=145,47,0 #912F00 lch=34,61,49 brown_red[1855][146,43,5](2.8)': 'background:#912F00;',
#  'beer srm 22 rgb=140,46,2 #8C2E02 lch=33,58,49 rust_brown[7383][139,49,3](1.0)': 'background:#8C2E02;',
#  'beer srm 23 rgb=131,37,1 #832501 lch=30,57,47 orange_red[6212][139,37,0](3.7)': 'background:#832501;',
#  'beer srm 24 rgb=126,31,1 #7E1F01 lch=28,56,45 kenyan_copper[4832][124,28,5](3.2)': 'background:#7E1F01;',
#  'beer srm 25 rgb=119,28,1 #771C01 lch=26,53,44 kenyan_copper[4832][124,28,5](2.2)': 'background:#771C01;',
#  'beer srm 26 rgb=114,27,0 #721B00 lch=25,52,45 cedar_wood_finish[2150][113,26,0](1.0)': 'background:#721B00;',
#  'beer srm 27 rgb=108,22,3 #6C1603 lch=23,49,42 reddy_brown[7159][110,16,5](2.2)': 'background:#6C1603;',
#  'beer srm 28 rgb=103,16,3 #671003 lch=21,48,39 reddy_brown[7159][110,16,5](3.5)': 'background:#671003;',
#  'beer srm 29 rgb=98,15,3 #620F03 lch=20,46,39 dark_tan[2898][102,16,16](4.2)': 'background:#620F03;',
#  'beer srm 30 rgb=91,13,3 #5B0D03 lch=18,43,38 deep_scarlet[3050][89,11,0](1.0)': 'background:#5B0D03;',
#  'beer srm 31 rgb=86,12,3 #560C03 lch=17,41,37 deep_scarlet[3050][89,11,0](2.2)': 'background:#560C03;',
#  'beer srm 32 rgb=83,11,6 #530B06 lch=16,39,35 mahogany[5461][78,6,6](2.8)': 'background:#530B06;',
#  'beer srm 33 rgb=80,11,8 #500B08 lch=15,37,33 mahogany[5461][78,6,6](1.4)': 'background:#500B08;',
#  'beer srm 34 rgb=74,6,5 #4A0605 lch=13,36,31 rustic_red[7387][72,4,4](1.4)': 'background:#4A0605;',
#  'beer srm 35 rgb=68,7,5 #440705 lch=12,33,30 burnt_maroon[1928][66,3,3](1.7)': 'background:#440705;',
#  'beer srm 36 rgb=66,8,7 #420807 lch=12,31,29 burnt_maroon[1928][66,3,3](2.4)': 'background:#420807;',
#  'beer srm 37 rgb=60,9,8 #3C0908 lch=10,28,28 chocolate[2301][55,2,2](3.0)': 'background:#3C0908;',
#  'beer srm 38 rgb=57,7,8 #390708 lch=9,27,25 chocolate[2301][55,2,2](2.2)': 'background:#390708;',
#  'beer srm 39 rgb=57,8,11 #39080B lch=10,26,23 aubergine[1193][59,9,16](1.4)': 'background:#39080B;',
#  'beer srm 40 rgb=53,9,10 #35090A lch=9,24,24 toast_lmu_20[8382][56,10,8](2.2)': 'background:#35090A;',
#  'black [3] #000000': 'background:#000000;',
#  'grey [105] #000000': 'background:#000000;',
#  'merlot [3] #730039': 'background:#730039;',
#  'PMS222  #70193D': 'background:#70193D;',
#  'tundora [2] #4A4244': 'background:#4A4244;',
#  'horoscope  #43373A': 'background:#43373A;',
#  'wine [2] #80013F': 'background:#80013F;',
#  'loyal  #28191D': 'background:#28191D;',
#  'arthouse  #4D202E': 'background:#4D202E;',
#  'verve  #5D2E3C': 'background:#5D2E3C;',
#  'extrovert  #752642': 'background:#752642;',
#  'encore  #54162C': 'background:#54162C;',
#  'siren [2] #7A013A': 'background:#7A013A;',
#  'black sheep  #3E393A': 'background:#3E393A;',
#  'spitfire  #381921': 'background:#381921;',
#  'black rose [2] #532934': 'background:#532934;',
#  'PMS216  #7C1E3F': 'background:#7C1E3F;',
#  'tempo  #462B31': 'background:#462B31;',
#  'wine berry [2] #522C35': 'background:#522C35;',
#  'dark crimson [2] #592734': 'background:#592734;',
#  'velocity  #4B4042': 'background:#4B4042;',
#  'PMS209  #75263D': 'background:#75263D;',
#  'double caffeine  #332729': 'background:#332729;',
#  'castro [2] #52001F': 'background:#52001F;',
#  'temptress [2] #3C2126': 'background:#3C2126;',
#  'aubergine [3] #372528': 'background:#372528;',
#  'red earth  #462028': 'background:#462028;',
#  'ravishing  #401A22': 'background:#401A22;',
#  'deep raspberry  #590021': 'background:#590021;',
#  'rendezvous  #561426': 'background:#561426;',
#  'afficionado  #453638': 'background:#453638;',
#  'double sidewinder  #473F40': 'background:#473F40;',
#  'jumpstart  #3E2025': 'background:#3E2025;',
#  'chocolate [9] #3D2327': 'background:#3D2327;',
#  'persian red [3] #4F212A': 'background:#4F212A;',
#  'attitude  #532B32': 'background:#532B32;',
#  'jon [2] #463D3E': 'background:#463D3E;',
#  'hot wired  #6F2637': 'background:#6F2637;',
#  'mayhem  #4D1B25': 'background:#4D1B25;',
#  'burgundy [5] #610023': 'background:#610023;',
#  'livid brown [2] #4D282E': 'background:#4D282E;',
#  'platypus  #3D3334': 'background:#3D3334;',
#  'cab sav [2] #4A2E32': 'background:#4A2E32;',
#  'red letter  #751631': 'background:#751631;',
#  'claret [3] #6E2233': 'background:#6E2233;',
#  'bordeaux [3] #5C0120': 'background:#5C0120;',
#  'maroon [13] #402327': 'background:#402327;',
#  'contraband  #462429': 'background:#462429;',
#  'PMS506  #7A2638': 'background:#7A2638;',
#  'red wine  #8C0034': 'background:#8C0034;',
#  'courage  #4B252A': 'background:#4B252A;',
#  'cowboy [2] #4D282D': 'background:#4D282D;',
#  'zibibbo  #51242B': 'background:#51242B;',
#  'breakfree  #65192A': 'background:#65192A;',
#  'night owl  #483335': 'background:#483335;',
#  'dark puce  #4F3A3C': 'background:#4F3A3C;',
#  'sidewinder  #554D4F': 'background:#554D4F;',
#  'violet red [9] #A50055': 'background:#A50055;',
#  'pale violet red [5] #8B475D': 'background:#8B475D;',
#  'scrumptious  #B71D62': 'background:#B71D62;',
#  'cannon pink [2] #8E5164': 'background:#8E5164;',
#  'china rose  #A8516E': 'background:#A8516E;',
#  'PMS226  #D60270': 'background:#D60270;',
#  'red purple [2] #E40078': 'background:#E40078;',
#  'dark grayish crimson  #594248': 'background:#594248;',
#  'disco [2] #892D4F': 'background:#892D4F;',
#  'irresistible [2] #B3446C': 'background:#B3446C;',
#  'raspberry rose  #B3446C': 'background:#B3446C;',
#  'mauve taupe  #915F6D': 'background:#915F6D;',
#  'raspberry glace  #915F6D': 'background:#915F6D;',
#  'fuchsia rose  #C74375': 'background:#C74375;',
#  'lipstick [3] #962C54': 'background:#962C54;',
#  'tickled pink  #962C54': 'background:#962C54;',
#  'strong rose  #A80054': 'background:#A80054;',
#  'rouge [3] #A94064': 'background:#A94064;',
#  'berry  #990F4B': 'background:#990F4B;',
#  'filmpro magenta  #AA305D': 'background:#AA305D;',
#  'memory  #7C5B63': 'background:#7C5B63;',
#  'cadillac [2] #984961': 'background:#984961;',
#  'maroon [13] #B03060': 'background:#B03060;',
#  'rich maroon  #B03060': 'background:#B03060;',
#  'cranberry [4] #B43864': 'background:#B43864;',
#  'pink panther  #B43864': 'background:#B43864;',
#  'rose dust  #9E5E6F': 'background:#9E5E6F;',
#  'vin rouge [2] #955264': 'background:#955264;',
#  'deep pink [5] #CB0162': 'background:#CB0162;',
#  'pink [9] #8B636C': 'background:#8B636C;',
#  'blush [4] #B44668': 'background:#B44668;',
#  'purple red  #990147': 'background:#990147;',
#  'PMS220  #AA004F': 'background:#AA004F;',
#  'colour me pink  #A90C50': 'background:#A90C50;',
#  'dogwood rose  #D71868': 'background:#D71868;',
#  'dark hot pink  #D90166': 'background:#D90166;',
#  'empress [2] #7C7173': 'background:#7C7173;',
#  'PMS221  #930042': 'background:#930042;',
#  'mortar [2] #565051': 'background:#565051;',
#  'don juan [2] #5A4F51': 'background:#5A4F51;',
#  'brownish purple  #76424E': 'background:#76424E;',
#  'renaissance  #885A64': 'background:#885A64;',
#  'night shadz [2] #AA375A': 'background:#AA375A;',
#  'dark pink [2] #CB416B': 'background:#CB416B;',
#  'emperor [2] #50494A': 'background:#50494A;',
#  'galaxy  #63464B': 'background:#63464B;',
#  'PMS208  #8E2344': 'background:#8E2344;',
#  'camelot [2] #803A4B': 'background:#803A4B;',
#  'zambezi [2] #685558': 'background:#685558;',
#  'moderate crimson  #A84A61': 'background:#A84A61;',
#  'hippie pink [2] #AE4560': 'background:#AE4560;',
#  'jazzberry jam [2] #C63061': 'background:#C63061;',
#  'spicy pink [3] #816E71': 'background:#816E71;',
#  'catawba  #703642': 'background:#703642;',
#  'purplish red  #B0054B': 'background:#B0054B;',
#  'light burgundy  #A8415B': 'background:#A8415B;',
#  'cerise [4] #DE0C62': 'background:#DE0C62;',
#  'matchmaker  #6D3540': 'background:#6D3540;',
#  'PMS215  #A50544': 'background:#A50544;',
#  'raspberry [5] #B00149': 'background:#B00149;',
#  'amaranth deep purple  #AB274F': 'background:#AB274F;',
#  'amaranth purple  #AB274F': 'background:#AB274F;',
#  'rose red [2] #C21E56': 'background:#C21E56;',
#  'eighth barista  #746466': 'background:#746466;',
#  'PMS214  #CC0256': 'background:#CC0256;',
#  'deep rose [2] #C74767': 'background:#C74767;',
#  'rubine red  #D10056': 'background:#D10056;',
#  'ruby [2] #E0115F': 'background:#E0115F;',
#  'geronimo  #88213C': 'background:#88213C;',
#  'sensual red  #902742': 'background:#902742;',
#  'pictorial carmine  #C30B4E': 'background:#C30B4E;',
#  'hibiscus [2] #B33654': 'background:#B33654;',
#  'light pink [7] #8B5F65': 'background:#8B5F65;',
#  'deep puce  #A95C68': 'background:#A95C68;',
#  'razzmatazz [2] #E30B5C': 'background:#E30B5C;',
#  'satellite  #554244': 'background:#554244;',
#  'rosehip  #842139': 'background:#842139;',
#  'purplish brown  #6B4247': 'background:#6B4247;',
#  'spellbound  #6D4A4E': 'background:#6D4A4E;',
#  'sargent pepper  #A34053': 'background:#A34053;',
#  'dark rose [2] #B5485D': 'background:#B5485D;',
#  'miss hussy  #C44762': 'background:#C44762;',
#  'strong raspberry  #A8003F': 'background:#A8003F;',
#  'big dip o ruby  #9C2542': 'background:#9C2542;',
#  'light maroon  #A24857': 'background:#A24857;',
#  'debian red  #D70A53': 'background:#D70A53;',
#  'popstar [2] #BE4E62': 'background:#BE4E62;',
#  'tapestry [2] #B37084': 'background:#B37084;',
#  'medium pink [5] #F36196': 'background:#F36196;',
#  'mystic [3] #D65282': 'background:#D65282;',
#  'fandango pink  #DE5285': 'background:#DE5285;',
#  'cerise pink  #EC3B83': 'background:#EC3B83;',
#  'pale violet red [5] #CD6889': 'background:#CD6889;',
#  'brilliant raspberry  #E75189': 'background:#E75189;',
#  'medium violet red [2] #DB7093': 'background:#DB7093;',
#  'pale red violet  #DB7093': 'background:#DB7093;',
#  'violet red pale  #DB7093': 'background:#DB7093;',
#  'dull pink  #D5869D': 'background:#D5869D;',
#  'french pink  #FD6C9E': 'background:#FD6C9E;',
#  'can [2] #D591A4': 'background:#D591A4;',
#  'vivid rose  #E70074': 'background:#E70074;',
#  'darkish pink  #DA467D': 'background:#DA467D;',
#  'grayish crimson  #A87D88': 'background:#A87D88;',
#  'french rose  #F64A8A': 'background:#F64A8A;',
#  'violet red [9] #F7468A': 'background:#F7468A;',
#  'PMS212  #F94F8E': 'background:#F94F8E;',
#  'deep blush [2] #E47698': 'background:#E47698;',
#  'PMS5215  #B5939B': 'background:#B5939B;',
#  'viola [2] #C58F9D': 'background:#C58F9D;',
#  'PMS204  #ED7A9E': 'background:#ED7A9E;',
#  'carnation pink [3] #FF7FA7': 'background:#FF7FA7;',
#  'ruber  #CE4676': 'background:#CE4676;',
#  'PMS806 2X  #F7027C': 'background:#F7027C;',
#  'mauve [2] #AE7181': 'background:#AE7181;',
#  'bright pink [2] #FF007F': 'background:#FF007F;',
#  'luminous vivid rose  #FF0080': 'background:#FF0080;',
#  'rose [4] #FF007F': 'background:#FF007F;',
#  'muted pink  #D1768F': 'background:#D1768F;',
#  'puce [2] #CC8899': 'background:#CC8899;',
#  'tickle me pink [2] #FC80A5': 'background:#FC80A5;',
#  'winter sky  #FF007C': 'background:#FF007C;',
#  'light crimson [2] #E78BA2': 'background:#E78BA2;',
#  'pig pink [2] #E78EA5': 'background:#E78EA5;',
#  'cinnamon satin  #CD607E': 'background:#CD607E;',
#  'blush [4] #DE5D83': 'background:#DE5D83;',
#  'high tea  #A18C90': 'background:#A18C90;',
#  'charm [2] #D0748B': 'background:#D0748B;',
#  'strawberry [2] #FC5A8D': 'background:#FC5A8D;',
#  'dusty grey [2] #A8989B': 'background:#A8989B;',
#  'grey pink  #C3909B': 'background:#C3909B;',
#  'pink [9] #CD919E': 'background:#CD919E;',
#  'cranberry [4] #DB5079': 'background:#DB5079;',
#  'PMS205  #E54C7C': 'background:#E54C7C;',
#  'turkish rose [2] #B57281': 'background:#B57281;',
#  'dark pink [2] #E75480': 'background:#E75480;',
#  'PMS507  #D8899B': 'background:#D8899B;',
#  'PMS213  #EA0F6B': 'background:#EA0F6B;',
#  'vintage  #A78087': 'background:#A78087;',
#  'rosy pink  #F6688E': 'background:#F6688E;',
#  'razzmatazz [2] #E3256B': 'background:#E3256B;',
#  'spicy pink [3] #897578': 'background:#897578;',
#  'minnelli  #B16B79': 'background:#B16B79;',
#  'cabaret [2] #D94972': 'background:#D94972;',
#  'sasquatch socks  #FF4681': 'background:#FF4681;',
#  'dusky pink [2] #CC7A8B': 'background:#CC7A8B;',
#  'light brilliant crimson  #FF658B': 'background:#FF658B;',
#  'shimmering blush  #D98695': 'background:#D98695;',
#  'carissma [2] #E68095': 'background:#E68095;',
#  'brilliant crimson  #E75177': 'background:#E75177;',
#  'wisteria [5] #A4878B': 'background:#A4878B;',
#  'anticipation  #A88A8E': 'background:#A88A8E;',
#  'warm pink  #FB5581': 'background:#FB5581;',
#  'bona fide  #97777B': 'background:#97777B;',
#  'bazaar [2] #98777B': 'background:#98777B;',
#  'vivid raspberry [2] #FF006C': 'background:#FF006C;',
#  'pinkish  #D46A7E': 'background:#D46A7E;',
#  'old pink  #C77986': 'background:#C77986;',
#  'ugly pink  #CD7584': 'background:#CD7584;',
#  'PMS1915  #F4547C': 'background:#F4547C;',
#  'careys pink [2] #C99AA0': 'background:#C99AA0;',
#  'cerise [4] #DE3163': 'background:#DE3163;',
#  'cerise red  #DE3163': 'background:#DE3163;',
#  'cherry [2] #DE3163': 'background:#DE3163;',
#  'rocket metallic  #8A7F80': 'background:#8A7F80;',
#  'rose gold  #B76E79': 'background:#B76E79;',
#  'old rose [2] #C87F89': 'background:#C87F89;',
#  'tonto  #9F9596': 'background:#9F9596;',
#  'light pink [7] #CD8C95': 'background:#CD8C95;',
#  'dusty pink  #D58A94': 'background:#D58A94;',
#  'PMS190  #FC758E': 'background:#FC758E;',
#  'rose pink [2] #F7879A': 'background:#F7879A;',
#  'brink pink  #FB607F': 'background:#FB607F;',
#  'greyish pink  #C88D94': 'background:#C88D94;',
#  'glamour puss  #F8748B': 'background:#F8748B;',
#  'carnation [2] #FD798F': 'background:#FD798F;',
#  'dusky rose  #BA6873': 'background:#BA6873;',
#  'PMS812  #FC2366': 'background:#FC2366;',
#  'ultra red  #FC6C85': 'background:#FC6C85;',
#  'wild watermelon [2] #FC6C85': 'background:#FC6C85;',
#  'light amaranth  #E78B96': 'background:#E78B96;',
#  'melanie [2] #E0B7C2': 'background:#E0B7C2;',
#  'cupid [2] #F5B2C5': 'background:#F5B2C5;',
#  'pink lace [2] #F6CCD7': 'background:#F6CCD7;',
#  'pale violet red [5] #FF82AB': 'background:#FF82AB;',
#  'PMS203  #F2AFC1': 'background:#F2AFC1;',
#  'pale light grayish crimson  #E7B8C4': 'background:#E7B8C4;',
#  'pastel pink [3] #FFBACD': 'background:#FFBACD;',
#  'pinky  #FC86AA': 'background:#FC86AA;',
#  'illusion [2] #EF95AE': 'background:#EF95AE;',
#  'tickle me pink [2] #FC89AC': 'background:#FC89AC;',
#  'pink swan [2] #BEB5B7': 'background:#BEB5B7;',
#  'pink flare [2] #E1C0C8': 'background:#E1C0C8;',
#  'pale crimson  #FFC2D1': 'background:#FFC2D1;',
#  'vanilla ice [3] #F3D9DF': 'background:#F3D9DF;',
#  'baker miller pink  #FF91AF': 'background:#FF91AF;',
#  'schauss pink  #FF91AF': 'background:#FF91AF;',
#  'careys pink [2] #D29EAA': 'background:#D29EAA;',
#  'faded pink  #DE9DAC': 'background:#DE9DAC;',
#  'mauvelous [2] #F091A9': 'background:#F091A9;',
#  'flamingo pink  #FC8EAC': 'background:#FC8EAC;',
#  'boutique  #DFACB7': 'background:#DFACB7;',
#  'very light crimson  #FF9EB6': 'background:#FF9EB6;',
#  'PMS663  #E2D3D6': 'background:#E2D3D6;',
#  'black shadows  #BFAFB2': 'background:#BFAFB2;',
#  'PMS1905  #FC9BB2': 'background:#FC9BB2;',
#  'pink [9] #EEA9B8': 'background:#EEA9B8;',
#  'blossom [2] #DCB4BC': 'background:#DCB4BC;',
#  'gelato  #DBB7BE': 'background:#DBB7BE;',
#  'rosa  #FE86A4': 'background:#FE86A4;',
#  'pink sherbet  #F78FA7': 'background:#F78FA7;',
#  'soft pink [2] #FDB0C0': 'background:#FDB0C0;',
#  'PMS679  #E5BFC6': 'background:#E5BFC6;',
#  'cherry blossom pink  #FFB7C5': 'background:#FFB7C5;',
#  'pale rose [4] #EFD6DA': 'background:#EFD6DA;',
#  'pretty in pink  #EFD6DA': 'background:#EFD6DA;',
#  'cherub [2] #F5D7DC': 'background:#F5D7DC;',
#  'bubble gum  #FFC1CC': 'background:#FFC1CC;',
#  'floyd  #DA9CA6': 'background:#DA9CA6;',
#  'wewak [2] #F19BAB': 'background:#F19BAB;',
#  'PMS1895  #FCBFC9': 'background:#FCBFC9;',
#  'PMS508  #E8A5AF': 'background:#E8A5AF;',
#  'PMS189  #FFA3B2': 'background:#FFA3B2;',
#  'light pink [7] #FFB6C1': 'background:#FFB6C1;',
#  'pink light  #FFB6C1': 'background:#FFB6C1;',
#  'PMS5165  #E0C9CC': 'background:#E0C9CC;',
#  'pink salmon  #FF91A4': 'background:#FF91A4;',
#  'salmon pink [2] #FF91A4': 'background:#FF91A4;',
#  'devoted  #E8CDD0': 'background:#E8CDD0;',
#  'salmon [8] #FF9BAA': 'background:#FF9BAA;',
#  'kidman  #CCB7B9': 'background:#CCB7B9;',
#  'PMS685  #EABFC4': 'background:#EABFC4;',
#  'pale amaranth  #FFC2C9': 'background:#FFC2C9;',
#  'light rose [2] #FFC5CB': 'background:#FFC5CB;',
#  'PMS197  #EF99A3': 'background:#EF99A3;',
#  'very light amaranth  #FF9EAA': 'background:#FF9EAA;',
#  'PMS509  #F2BABF': 'background:#F2BABF;',
#  'PMS670  #F2D6D8': 'background:#F2D6D8;',
#  'very pale crimson  #FFE2E9': 'background:#FFE2E9;',
#  'bon jour [2] #E5E0E1': 'background:#E5E0E1;',
#  'carousel pink [2] #F8DBE0': 'background:#F8DBE0;',
#  'pale pink [4] #FADADD': 'background:#FADADD;',
#  'temptress [2] #3B000B': 'background:#3B000B;',
#  'diesel [2] #130000': 'background:#130000;',
#  'very deep reddish brown  #1D0000': 'background:#1D0000;',
#  'very reddish brown  #1D1111': 'background:#1D1111;',
#  'charcoal [3] #191818': 'background:#191818;',
#  'sepia [6] #2B0202': 'background:#2B0202;',
#  'sepia black  #2B0202': 'background:#2B0202;',
#  'toast lmu 15  #2A0F10': 'background:#2A0F10;',
#  'dark maroon  #3C0008': 'background:#3C0008;',
#  'gondola [2] #261414': 'background:#261414;',
#  'very dark brown [2] #1D0200': 'background:#1D0200;',
#  'chocolate [9] #370202': 'background:#370202;',
#  'beer srm 40  #35090A': 'background:#35090A;',
#  'beer srm 38  #390708': 'background:#390708;',
#  'licorice [3] #1A1110': 'background:#1A1110;',
#  'night rider [2] #1F120F': 'background:#1F120F;',
#  'kilamanjaro [2] #240C02': 'background:#240C02;',
#  'coffee bean [2] #2A140E': 'background:#2A140E;',
#  'cuban tan [2] #2A140E': 'background:#2A140E;',
#  'marlin [2] #2A140E': 'background:#2A140E;',
#  'blackwood [2] #261105': 'background:#261105;',
#  'wood bark [2] #261105': 'background:#261105;',
#  'PMS504  #511E26': 'background:#511E26;',
#  'maroon [13] #650021': 'background:#650021;',
#  'x factor  #681B2B': 'background:#681B2B;',
#  'havana [2] #3B2B2C': 'background:#3B2B2C;',
#  'jarrah [2] #3B2B2C': 'background:#3B2B2C;',
#  'PMS505  #661E2B': 'background:#661E2B;',
#  'speed demon  #551B24': 'background:#551B24;',
#  'dark amaranth  #59272D': 'background:#59272D;',
#  'vanquish  #63272F': 'background:#63272F;',
#  'i c red  #7A2031': 'background:#7A2031;',
#  'dark scarlet [2] #560319': 'background:#560319;',
#  'bulgarian rose [2] #482427': 'background:#482427;',
#  'puce red  #722F37': 'background:#722F37;',
#  'wine [2] #722F37': 'background:#722F37;',
#  'cab sav [2] #4D0A18': 'background:#4D0A18;',
#  'renegade  #592228': 'background:#592228;',
#  'avant garde  #5C2C30': 'background:#5C2C30;',
#  'windswept  #434141': 'background:#434141;',
#  'reddish brownish black  #1D1A1A': 'background:#1D1A1A;',
#  'aubergine [3] #3B0910': 'background:#3B0910;',
#  'double barbecue  #282020': 'background:#282020;',
#  'maxwell smart  #2A2525': 'background:#2A2525;',
#  'night rider [2] #332E2E': 'background:#332E2E;',
#  'red baron  #511D22': 'background:#511D22;',
#  'sheer black  #332F2F': 'background:#332F2F;',
#  'barbecue  #363030': 'background:#363030;',
#  'half bokara grey  #353333': 'background:#353333;',
#  'half diesel  #353131': 'background:#353131;',
#  'lava [2] #591F25': 'background:#591F25;',
#  'heath [2] #4F2A2C': 'background:#4F2A2C;',
#  'pohutukawa [2] #651C26': 'background:#651C26;',
#  'style pasifika hibiscus blood  #651C26': 'background:#651C26;',
#  'eclipse [2] #3F3939': 'background:#3F3939;',
#  'salsa  #770C25': 'background:#770C25;',
#  'rustic red [2] #3A181A': 'background:#3A181A;',
#  'deep crimson  #590016': 'background:#590016;',
#  'cave rock  #372C2C': 'background:#372C2C;',
#  'madam m  #610C1D': 'background:#610C1D;',
#  'livewire  #6D1C27': 'background:#6D1C27;',
#  'jazz [2] #5F2C2F': 'background:#5F2C2F;',
#  'jalapeno  #701C28': 'background:#701C28;',
#  'wine red  #7B0323': 'background:#7B0323;',
#  'hot chile [2] #6B252C': 'background:#6B252C;',
#  'monarch [2] #6B252C': 'background:#6B252C;',
#  'western red [2] #6B252C': 'background:#6B252C;',
#  'half barista  #513F3F': 'background:#513F3F;',
#  'scarlett [2] #7E2530': 'background:#7E2530;',
#  'antique ruby  #841B2D': 'background:#841B2D;',
#  'maroon oak  #520C17': 'background:#520C17;',
#  'persian red [3] #520C17': 'background:#520C17;',
#  'crater brown [2] #462425': 'background:#462425;',
#  'style pasifika red soil  #4E2728': 'background:#4E2728;',
#  'volcano [2] #4E2728': 'background:#4E2728;',
#  'lonestar [2] #522426': 'background:#522426;',
#  'woody brown [2] #483131': 'background:#483131;',
#  'razzamatazz  #701F28': 'background:#701F28;',
#  'red berry [2] #701F28': 'background:#701F28;',
#  'earlybird  #513939': 'background:#513939;',
#  'code red  #880025': 'background:#880025;',
#  'beer srm 39  #39080B': 'background:#39080B;',
#  'jon [2] #3B1F1F': 'background:#3B1F1F;',
#  'burnt crimson [2] #582124': 'background:#582124;',
#  'indian red [8] #4E2F2F': 'background:#4E2F2F;',
#  'buccaneer [2] #622F30': 'background:#622F30;',
#  'congo brown [2] #593737': 'background:#593737;',
#  'paprika [2] #8D0226': 'background:#8D0226;',
#  'claret [3] #680018': 'background:#680018;',
#  'venetian red [4] #5B1F22': 'background:#5B1F22;',
#  'red devil [2] #662A2C': 'background:#662A2C;',
#  'burgundy [5] #800020': 'background:#800020;',
#  'japanese maple [2] #672F30': 'background:#672F30;',
#  'tamarillo [2] #752B2F': 'background:#752B2F;',
#  'bullseye  #7D222B': 'background:#7D222B;',
#  'seal brown  #321414': 'background:#321414;',
#  'tamarind [2] #341515': 'background:#341515;',
#  'nelson red  #4F2525': 'background:#4F2525;',
#  'deep impact  #672729': 'background:#672729;',
#  'dark tan [5] #612D2D': 'background:#612D2D;',
#  'red ochre  #612D2D': 'background:#612D2D;',
#  'dynamite  #6F282B': 'background:#6F282B;',
#  'PMS188  #7C2128': 'background:#7C2128;',
#  'cocoa brown [3] #301F1E': 'background:#301F1E;',
#  'cocoa bean [2] #481C1C': 'background:#481C1C;',
#  'mahogany [6] #492625': 'background:#492625;',
#  'filmpro burnt sienna  #522C2B': 'background:#522C2B;',
#  'reddish brown [2] #592727': 'background:#592727;',
#  'PMS490  #5B2626': 'background:#5B2626;',
#  'burnt sienna [5] #683332': 'background:#683332;',
#  'persian plum [2] #683332': 'background:#683332;',
#  'toast lmu 20  #380A08': 'background:#380A08;',
#  'dark sienna  #3C1414': 'background:#3C1414;',
#  'rialto  #4C2322': 'background:#4C2322;',
#  'cowboy [2] #443736': 'background:#443736;',
#  'jarrah tree  #52312F': 'background:#52312F;',
#  'barista  #453837': 'background:#453837;',
#  'coco  #682828': 'background:#682828;',
#  'merlot [3] #831923': 'background:#831923;',
#  'PMS438  #593F3D': 'background:#593F3D;',
#  'beer srm 37  #3C0908': 'background:#3C0908;',
#  'burnt maroon  #420303': 'background:#420303;',
#  'PMS497  #512826': 'background:#512826;',
#  'PMS491  #752828': 'background:#752828;',
#  'patio red  #6D3331': 'background:#6D3331;',
#  'deep brown [2] #410200': 'background:#410200;',
#  'beer srm 36  #420807': 'background:#420807;',
#  'deep amaranth  #59000B': 'background:#59000B;',
#  'toorak  #392523': 'background:#392523;',
#  'PMS4975  #441E1C': 'background:#441E1C;',
#  'old burgundy  #43302E': 'background:#43302E;',
#  'rata  #5D1F1E': 'background:#5D1F1E;',
#  'red oxide [2] #5D1F1E': 'background:#5D1F1E;',
#  'PMS439  #493533': 'background:#493533;',
#  'fahrenheit  #672E2B': 'background:#672E2B;',
#  'beer srm 35  #440705': 'background:#440705;',
#  'stingray  #453533': 'background:#453533;',
#  'cherrywood [2] #4E312E': 'background:#4E312E;',
#  'cajun  #662F2B': 'background:#662F2B;',
#  'kenyan copper [2] #6C322E': 'background:#6C322E;',
#  'beer srm 34  #4A0605': 'background:#4A0605;',
#  'dried blood  #4B0101': 'background:#4B0101;',
#  'livid brown [2] #312A29': 'background:#312A29;',
#  'rosewood [2] #65000B': 'background:#65000B;',
#  'moccaccino [2] #582F2B': 'background:#582F2B;',
#  'hot n spicy  #6B2320': 'background:#6B2320;',
#  'prune  #701C1C': 'background:#701C1C;',
#  'van cleef [2] #523936': 'background:#523936;',
#  'crown of thorns [2] #771F1F': 'background:#771F1F;',
#  'espresso [2] #4E312D': 'background:#4E312D;',
#  'PMS1817  #5B2D28': 'background:#5B2D28;',
#  'beer srm 33  #500B08': 'background:#500B08;',
#  'diesel [2] #322C2B': 'background:#322C2B;',
#  'style pasifika burnt charcoal  #322C2B': 'background:#322C2B;',
#  'double barista  #392C2A': 'background:#392C2A;',
#  'pioneer red  #642620': 'background:#642620;',
#  'echo  #483C3A': 'background:#483C3A;',
#  'heatwave  #6E2620': 'background:#6E2620;',
#  'PMS1810  #7C211E': 'background:#7C211E;',
#  'falu red  #801818': 'background:#801818;',
#  'deep reddish brown  #590000': 'background:#590000;',
#  'sepia [6] #3A2F2D': 'background:#3A2F2D;',
#  'style pasifika black tan  #3A2F2D': 'background:#3A2F2D;',
#  'scoria  #532620': 'background:#532620;',
#  'barn red [2] #602821': 'background:#602821;',
#  'tipping point  #612C25': 'background:#612C25;',
#  'redwood [3] #5B342E': 'background:#5B342E;',
#  'red sienna  #5F312A': 'background:#5F312A;',
#  'up maroon  #7B1113': 'background:#7B1113;',
#  'kakaramea  #6E2C25': 'background:#6E2C25;',
#  'crimson [2] #8C000F': 'background:#8C000F;',
#  'PMS498  #6D332B': 'background:#6D332B;',
#  'bean [2] #3D0C02': 'background:#3D0C02;',
#  'black bean [3] #3D0C02': 'background:#3D0C02;',
#  'beer srm 32  #530B06': 'background:#530B06;',
#  'hot chocolate  #3D2622': 'background:#3D2622;',
#  'digeridoo  #452924': 'background:#452924;',
#  'style pasifika brown earth  #452924': 'background:#452924;',
#  'hinau  #482A25': 'background:#482A25;',
#  'red planet  #5A2019': 'background:#5A2019;',
#  'hukanui  #572A23': 'background:#572A23;',
#  'caput mortuum  #592720': 'background:#592720;',
#  'kwila  #6D332A': 'background:#6D332A;',
#  'warmed brown  #4A302B': 'background:#4A302B;',
#  'jarrah stain  #57332C': 'background:#57332C;',
#  'toast lmu 25  #49140B': 'background:#49140B;',
#  'beer srm 31  #560C03': 'background:#560C03;',
#  'blood  #770001': 'background:#770001;',
#  'cedar [3] #463430': 'background:#463430;',
#  'rattlesnake  #463835': 'background:#463835;',
#  'oiled cedar [2] #66362D': 'background:#66362D;',
#  'meranti [2] #6B342A': 'background:#6B342A;',
#  'deep scarlet  #590B00': 'background:#590B00;',
#  'beer srm 30  #5B0D03': 'background:#5B0D03;',
#  'rebel [2] #453430': 'background:#453430;',
#  'pepperwood  #542F27': 'background:#542F27;',
#  'rock [2] #4D3833': 'background:#4D3833;',
#  'web maroon  #800000': 'background:#800000;',
#  'triple lumberjack  #5A372F': 'background:#5A372F;',
#  'metallic copper [2] #71291D': 'background:#71291D;',
#  'beer srm 29  #620F03': 'background:#620F03;',
#  'beer srm 28  #671003': 'background:#671003;',
#  'gondola [2] #373332': 'background:#373332;',
#  'reddy brown  #6E1005': 'background:#6E1005;',
#  'dark burgundy  #770F05': 'background:#770F05;',
#  'deep maroon  #820000': 'background:#820000;',
#  'dark red [2] #840000': 'background:#840000;',
#  'deep red [2] #850101': 'background:#850101;',
#  'komakorau  #64352A': 'background:#64352A;',
#  'red [12] #8B0000': 'background:#8B0000;',
#  'pueblo [2] #6E3326': 'background:#6E3326;',
#  'french puce  #4E1609': 'background:#4E1609;',
#  'short black  #42231B': 'background:#42231B;',
#  'PMS4695  #51261C': 'background:#51261C;',
#  'dark liver [2] #543D37': 'background:#543D37;',
#  'dark oak [2] #55342B': 'background:#55342B;',
#  'liver [4] #6C2E1F': 'background:#6C2E1F;',
#  'PMS483  #6B3021': 'background:#6B3021;',
#  'beer srm 27  #6C1603': 'background:#6C1603;',
#  'hairy heath [2] #633528': 'background:#633528;',
#  'dark ginger  #473029': 'background:#473029;',
#  'mocha [3] #782D19': 'background:#782D19;',
#  'deep vermilion  #591600': 'background:#591600;',
#  'PMS440  #3F302B': 'background:#3F302B;',
#  'baked earth  #493028': 'background:#493028;',
#  'cedar wood finish  #711A00': 'background:#711A00;',
#  'beer srm 25  #771C01': 'background:#771C01;',
#  'PMS175  #6D3321': 'background:#6D3321;',
#  'purple brown  #673A3F': 'background:#673A3F;',
#  'ribbon [2] #71333C': 'background:#71333C;',
#  'PMS1955  #931638': 'background:#931638;',
#  'pink raspberry  #980036': 'background:#980036;',
#  'french wine  #AC1E44': 'background:#AC1E44;',
#  'vivid raspberry [2] #E70057': 'background:#E70057;',
#  'lollipop  #7F2838': 'background:#7F2838;',
#  'raspberry [5] #7F2838': 'background:#7F2838;',
#  'erotic  #94414C': 'background:#94414C;',
#  'deep taupe  #7E5E60': 'background:#7E5E60;',
#  'dingy dungeon  #C53151': 'background:#C53151;',
#  'filmpro deep red  #90243A': 'background:#90243A;',
#  'solid pink [2] #893843': 'background:#893843;',
#  'falcon [2] #6E5A5B': 'background:#6E5A5B;',
#  'ruby [2] #CA0147': 'background:#CA0147;',
#  'lipstick [3] #D5174E': 'background:#D5174E;',
#  'ua red  #D9004C': 'background:#D9004C;',
#  'candy floss  #9F263D': 'background:#9F263D;',
#  'deep carmine  #A9203E': 'background:#A9203E;',
#  'bright maroon  #C32148': 'background:#C32148;',
#  'maroon [13] #C32148': 'background:#C32148;',
#  'maroon flush  #C32148': 'background:#C32148;',
#  'moderate amaranth  #A84A55': 'background:#A84A55;',
#  'spanish carmine  #D10047': 'background:#D10047;',
#  'merlot [3] #73343A': 'background:#73343A;',
#  'paprika [2] #7C2D37': 'background:#7C2D37;',
#  'ferra [2] #704F50': 'background:#704F50;',
#  'rouge [3] #AB1239': 'background:#AB1239;',
#  'PMS206  #D30547': 'background:#D30547;',
#  'dove grey [2] #6D6C6C': 'background:#6D6C6C;',
#  'PMS198  #772D35': 'background:#772D35;',
#  'brunette  #634041': 'background:#634041;',
#  'solar flare  #693E40': 'background:#693E40;',
#  'matterhorn [2] #524B4B': 'background:#524B4B;',
#  'rock n roll  #9D002F': 'background:#9D002F;',
#  'reddish brownish grey  #595353': 'background:#595353;',
#  'PMS1945  #A80C35': 'background:#A80C35;',
#  'cordovan  #893F45': 'background:#893F45;',
#  'zambezi [2] #6B5A5A': 'background:#6B5A5A;',
#  'rose red [2] #BE013C': 'background:#BE013C;',
#  'identity  #6E6767': 'background:#6E6767;',
#  'french raspberry  #C72C48': 'background:#C72C48;',
#  'weathered grey  #776F6F': 'background:#776F6F;',
#  'brick red [3] #CB4154': 'background:#CB4154;',
#  'spanish crimson  #E51A4C': 'background:#E51A4C;',
#  'dark grayish reddish brown  #594242': 'background:#594242;',
#  'woody brown [2] #554545': 'background:#554545;',
#  'shiraz [2] #842833': 'background:#842833;',
#  'tosca [2] #744042': 'background:#744042;',
#  'PMS194  #992135': 'background:#992135;',
#  'quarter barista  #614F4F': 'background:#614F4F;',
#  'vivid burgundy  #9F1D35': 'background:#9F1D35;',
#  'zinger  #873D42': 'background:#873D42;',
#  'vibe  #AC3142': 'background:#AC3142;',
#  'la bamba  #A43F48': 'background:#A43F48;',
#  'knock out  #C81641': 'background:#C81641;',
#  'dusty rose [2] #856363': 'background:#856363;',
#  'english red [2] #AB4B52': 'background:#AB4B52;',
#  'rosy brown [5] #8B6969': 'background:#8B6969;',
#  'rosybrown [4] #8B6969': 'background:#8B6969;',
#  'PMS1925  #E00747': 'background:#E00747;',
#  'fast lane  #892431': 'background:#892431;',
#  'PMS202  #8C2633': 'background:#8C2633;',
#  'PMS201  #A32638': 'background:#A32638;',
#  'crash hot  #AF2E40': 'background:#AF2E40;',
#  'rose taupe  #905D5D': 'background:#905D5D;',
#  'utah crimson  #D3003F': 'background:#D3003F;',
#  'carmine [4] #D70040': 'background:#D70040;',
#  'rich carmine  #D70040': 'background:#D70040;',
#  'copper rose  #996666': 'background:#996666;',
#  'sangria [2] #822A32': 'background:#822A32;',
#  'adrenalin junkie  #7F3136': 'background:#7F3136;',
#  'salmon [8] #6F4242': 'background:#6F4242;',
#  'pirate  #902F37': 'background:#902F37;',
#  'crossroads  #734949': 'background:#734949;',
#  'tuscan red [2] #7C4848': 'background:#7C4848;',
#  'cha  #8C3F42': 'background:#8C3F42;',
#  'hot stuff  #874748': 'background:#874748;',
#  'orbit  #874748': 'background:#874748;',
#  'smokey topaz  #933D41': 'background:#933D41;',
#  'smoky topaz  #933D41': 'background:#933D41;',
#  'PMS696  #8E4749': 'background:#8E4749;',
#  'bombshell  #AE2F3E': 'background:#AE2F3E;',
#  'PMS1935  #C10538': 'background:#C10538;',
#  'rose vale  #AB4E52': 'background:#AB4E52;',
#  'permanent red violet  #DB2645': 'background:#DB2645;',
#  'PMS697  #7F383A': 'background:#7F383A;',
#  'stiletto [2] #833D3E': 'background:#833D3E;',
#  'buccaneer [2] #6E5150': 'background:#6E5150;',
#  'roadster  #9F2C37': 'background:#9F2C37;',
#  'red tape  #B3002F': 'background:#B3002F;',
#  'PMS4985  #844949': 'background:#844949;',
#  'filmpro fire red  #A5333C': 'background:#A5333C;',
#  'crimson glory  #BE0032': 'background:#BE0032;',
#  'PMS703  #B73844': 'background:#B73844;',
#  'PMS200  #C41E3A': 'background:#C41E3A;',
#  'cardinal [3] #C41E3A': 'background:#C41E3A;',
#  'dusty red  #B9484E': 'background:#B9484E;',
#  'memphis belle  #CA2F43': 'background:#CA2F43;',
#  'PMS199  #D81C3F': 'background:#D81C3F;',
#  'flame red [2] #86282E': 'background:#86282E;',
#  'monza [2] #86282E': 'background:#86282E;',
#  'rocket  #86282E': 'background:#86282E;',
#  'deep coffee  #704241': 'background:#704241;',
#  'roast coffee  #704241': 'background:#704241;',
#  'xotic  #863336': 'background:#863336;',
#  'PMS492  #913338': 'background:#913338;',
#  'strong crimson  #A8002A': 'background:#A8002A;',
#  'japanese carmine  #9D2933': 'background:#9D2933;',
#  'rosewood [2] #8F3E3F': 'background:#8F3E3F;',
#  'glitterbug  #A92A37': 'background:#A92A37;',
#  'copper rust [2] #944747': 'background:#944747;',
#  'red [12] #C40233': 'background:#C40233;',
#  'aphrodisiac  #A64D4E': 'background:#A64D4E;',
#  'warhol  #9B615F': 'background:#9B615F;',
#  'crimson [2] #DC143C': 'background:#DC143C;',
#  'rusty red [2] #DA2C43': 'background:#DA2C43;',
#  'sanguine brown [2] #6C3736': 'background:#6C3736;',
#  'old brick [2] #8A3335': 'background:#8A3335;',
#  'bright red [3] #922A31': 'background:#922A31;',
#  'chaos  #922A31': 'background:#922A31;',
#  'vermilion [4] #922A31': 'background:#922A31;',
#  'lotus [2] #863C3C': 'background:#863C3C;',
#  'well read [2] #8E3537': 'background:#8E3537;',
#  'red hot  #952B32': 'background:#952B32;',
#  'alabama crimson  #AF002A': 'background:#AF002A;',
#  'punch [2] #A83239': 'background:#A83239;',
#  'lipstick red  #C0022F': 'background:#C0022F;',
#  'vivid crimson [2] #CC0033': 'background:#CC0033;',
#  'moderate red  #A84A4A': 'background:#A84A4A;',
#  'cherry [2] #CF0234': 'background:#CF0234;',
#  'PMS192  #E5053A': 'background:#E5053A;',
#  'quickstep  #A7615F': 'background:#A7615F;',
#  'bittersweet shimmer  #BF4F51': 'background:#BF4F51;',
#  'burgundy [5] #900020': 'background:#900020;',
#  'rose ebony  #674846': 'background:#674846;',
#  'flash point  #932C31': 'background:#932C31;',
#  'indian red [8] #8B3A3A': 'background:#8B3A3A;',
#  'indianred [4] #8B3A3A': 'background:#8B3A3A;',
#  'mexican red [2] #9B3D3D': 'background:#9B3D3D;',
#  'terracotta pink  #9B3D3D': 'background:#9B3D3D;',
#  'ameile  #904947': 'background:#904947;',
#  'bliss  #B3393E': 'background:#B3393E;',
#  'au chico [2] #97605D': 'background:#97605D;',
#  'tall poppy [2] #853534': 'background:#853534;',
#  'guardsman red [2] #952E31': 'background:#952E31;',
#  'PMS1807  #A03033': 'background:#A03033;',
#  'PMS187  #AF1E2D': 'background:#AF1E2D;',
#  'dorado [2] #6B5755': 'background:#6B5755;',
#  'hot spot  #B22833': 'background:#B22833;',
#  'cincinnati  #A5403F': 'background:#A5403F;',
#  'get reddy  #AD3539': 'background:#AD3539;',
#  'havoc  #AD3539': 'background:#AD3539;',
#  'lusty [2] #782E2C': 'background:#782E2C;',
#  'brown [11] #802A2A': 'background:#802A2A;',
#  'intrigue  #814743': 'background:#814743;',
#  'red pepper  #BB112A': 'background:#BB112A;',
#  'roof terracotta [2] #A14743': 'background:#A14743;',
#  'alter ego  #AB4C48': 'background:#AB4C48;',
#  'dull red  #BB3F3F': 'background:#BB3F3F;',
#  'pharlap [2] #826663': 'background:#826663;',
#  'style pasifika red frangipani  #832B29': 'background:#832B29;',
#  'totem pole [2] #883531': 'background:#883531;',
#  'tabasco [2] #8E3A36': 'background:#8E3A36;',
#  'smashing  #AD0020': 'background:#AD0020;',
#  'wenge  #645452': 'background:#645452;',
#  'afterburner  #983D39': 'background:#983D39;',
#  'style pasifika red pineapple  #983D39': 'background:#983D39;',
#  'milano red [2] #9E3332': 'background:#9E3332;',
#  'upsdell red  #AE2029': 'background:#AE2029;',
#  'russett [2] #755A57': 'background:#755A57;',
#  'reddish  #C44240': 'background:#C44240;',
#  'geranium lake  #E31230': 'background:#E31230;',
#  'jasper [2] #D73B3E': 'background:#D73B3E;',
#  'alizarin crimson  #E32636': 'background:#E32636;',
#  'rose madder [2] #E32636': 'background:#E32636;',
#  'ruby red  #9B111E': 'background:#9B111E;',
#  'forbidden  #B04640': 'background:#B04640;',
#  'flush mahogany  #CA3435': 'background:#CA3435;',
#  'chestnut [5] #B94E48': 'background:#B94E48;',
#  'deep chestnut  #B94E48': 'background:#B94E48;',
#  'PMS711  #D12D33': 'background:#D12D33;',
#  'medium candy apple red  #E2062C': 'background:#E2062C;',
#  'sunset [3] #C0514A': 'background:#C0514A;',
#  'raging bull  #7F2F2A': 'background:#7F2F2A;',
#  'erica  #81332D': 'background:#81332D;',
#  'firebrick [6] #8E2323': 'background:#8E2323;',
#  'PMS704  #9E2828': 'background:#9E2828;',
#  'auburn [2] #A52A2A': 'background:#A52A2A;',
#  'red brown [2] #A52A2A': 'background:#A52A2A;',
#  'fusion  #98463E': 'background:#98463E;',
#  'kachow  #A23A34': 'background:#A23A34;',
#  'whizz bang  #A23A34': 'background:#A23A34;',
#  'moulin rouge  #AD463F': 'background:#AD463F;',
#  'PMS186  #CE1126': 'background:#CE1126;',
#  'quarter felix  #746765': 'background:#746765;',
#  'apple blossom [2] #A95249': 'background:#A95249;',
#  'persian red [3] #CC3333': 'background:#CC3333;',
#  'PMS1797  #CC2D30': 'background:#CC2D30;',
#  'amaranth red  #D3212D': 'background:#D3212D;',
#  'redwood [3] #A45A52': 'background:#A45A52;',
#  'matrix [2] #B05D54': 'background:#B05D54;',
#  'PMS185  #E8112D': 'background:#E8112D;',
#  'scarlett [2] #950015': 'background:#950015;',
#  'mustang  #7F352E': 'background:#7F352E;',
#  'vivid auburn  #922724': 'background:#922724;',
#  'roller coaster  #923830': 'background:#923830;',
#  'thunderbird [2] #923830': 'background:#923830;',
#  'poppy  #AC0019': 'background:#AC0019;',
#  'PMS1805  #AF2626': 'background:#AF2626;',
#  'sweet brown  #A83731': 'background:#A83731;',
#  'el salva [2] #8F4E45': 'background:#8F4E45;',
#  'cognac [2] #9A463D': 'background:#9A463D;',
#  'fire engine red [2] #CE2029': 'background:#CE2029;',
#  'flair  #B94B42': 'background:#B94B42;',
#  'bring it on  #C3423B': 'background:#C3423B;',
#  'spanish red  #E60026': 'background:#E60026;',
#  "giant's club  #B05C52": 'background:#B05C52;',
#  'scarlet [5] #8C1717': 'background:#8C1717;',
#  'vixen  #81342B': 'background:#81342B;',
#  'sunspot  #7E372E': 'background:#7E372E;',
#  'crab apple [2] #87382F': 'background:#87382F;',
#  'congo brown [2] #654D49': 'background:#654D49;',
#  'red robin [2] #7D4138': 'background:#7D4138;',
#  'strong amaranth  #A80015': 'background:#A80015;',
#  'artefact  #5D5250': 'background:#5D5250;',
#  'del toro  #B11D20': 'background:#B11D20;',
#  'mojo [2] #97463C': 'background:#97463C;',
#  'hot august  #9A463B': 'background:#9A463B;',
#  'half lumberjack  #845A53': 'background:#845A53;',
#  'medium carmine  #AF4035': 'background:#AF4035;',
#  'pale carmine  #AF4035': 'background:#AF4035;',
#  'lava [2] #CF1020': 'background:#CF1020;',
#  'moderate scarlet  #A8554A': 'background:#A8554A;',
#  'PMS1795  #D62828': 'background:#D62828;',
#  'promise  #936962': 'background:#936962;',
#  'brown madder  #DB2929': 'background:#DB2929;',
#  'cadmium red  #E30022': 'background:#E30022;',
#  'permanent geranium lake  #E12C2C': 'background:#E12C2C;',
#  'lexington  #683E37': 'background:#683E37;',
#  'crown of thorns [2] #763C33': 'background:#763C33;',
#  'spartan crimson  #9E1316': 'background:#9E1316;',
#  'liver [4] #674C47': 'background:#674C47;',
#  'medium taupe  #674C47': 'background:#674C47;',
#  'bole  #79443B': 'background:#79443B;',
#  'medium tuscan red  #79443B': 'background:#79443B;',
#  'prairie sand [2] #883C32': 'background:#883C32;',
#  'cracker  #963128': 'background:#963128;',
#  'carnelian  #B31B1B': 'background:#B31B1B;',
#  'cornell red  #B31B1B': 'background:#B31B1B;',
#  'international orange [3] #C0362C': 'background:#C0362C;',
#  'venetian red [4] #D41A1F': 'background:#D41A1F;',
#  'vivid amaranth  #E7001D': 'background:#E7001D;',
#  'daredevil  #CB483B': 'background:#CB483B;',
#  'tomahawk  #524340': 'background:#524340;',
#  'mocha [3] #6F372D': 'background:#6F372D;',
#  'PMS181  #7C2D23': 'background:#7C2D23;',
#  'metallic copper [2] #6E3D34': 'background:#6E3D34;',
#  'PMS499  #7A382D': 'background:#7A382D;',
#  'tamarillo [2] #991613': 'background:#991613;',
#  'pulse  #A41D19': 'background:#A41D19;',
#  'bonfire  #A62A20': 'background:#A62A20;',
#  'harvard crimson  #C90016': 'background:#C90016;',
#  'crail [2] #A65648': 'background:#A65648;',
#  'dark chestnut  #986960': 'background:#986960;',
#  'lust  #E62020': 'background:#E62020;',
#  'dawnbreaker  #813125': 'background:#813125;',
#  'lumberjack  #724B43': 'background:#724B43;',
#  'rust [3] #8B4235': 'background:#8B4235;',
#  'ironstone [2] #86483C': 'background:#86483C;',
#  'kamikaze  #A43F30': 'background:#A43F30;',
#  'PMS180  #C13828': 'background:#C13828;',
#  'pursuit  #D9251D': 'background:#D9251D;',
#  'double lumberjack  #633E36': 'background:#633E36;',
#  'western red cedar  #7A372A': 'background:#7A372A;',
#  'burnt umber [3] #8A3324': 'background:#8A3324;',
#  'darkish red  #A90308': 'background:#A90308;',
#  'coral [9] #8B3E2F': 'background:#8B3E2F;',
#  'embers [2] #8C3F30': 'background:#8C3F30;',
#  'copper fire  #925345': 'background:#925345;',
#  'ku crimson  #E8000D': 'background:#E8000D;',
#  'oh behave  #BE523F': 'background:#BE523F;',
#  'clementine [2] #C14F3B': 'background:#C14F3B;',
#  'blood red  #980002': 'background:#980002;',
#  'tomato [5] #8B3626': 'background:#8B3626;',
#  'copperhead  #755148': 'background:#755148;',
#  'brick [2] #A03623': 'background:#A03623;',
#  'brownish red  #9E3623': 'background:#9E3623;',
#  'balloon  #C14D36': 'background:#C14D36;',
#  'grenadier [2] #C14D36': 'background:#C14D36;',
#  'cadmium red deep  #E3170D': 'background:#E3170D;',
#  'crimson red  #990000': 'background:#990000;',
#  'ou crimson red  #990000': 'background:#990000;',
#  'stizza  #990000': 'background:#990000;',
#  'usc cardinal  #990000': 'background:#990000;',
#  'deep red [2] #9A0200': 'background:#9A0200;',
#  'teranova  #7A3A2B': 'background:#7A3A2B;',
#  'rough n tumble  #5B4C48': 'background:#5B4C48;',
#  'scorched clay  #7E3C2D': 'background:#7E3C2D;',
#  'countdown  #922F1D': 'background:#922F1D;',
#  'dark candy apple red  #A40000': 'background:#A40000;',
#  'strong red  #A80000': 'background:#A80000;',
#  'PMS484  #9B301C': 'background:#9B301C;',
#  'boston university red  #CC0000': 'background:#CC0000;',
#  'rosso corsa  #D40000': 'background:#D40000;',
#  'dark pastel red  #C23B22': 'background:#C23B22;',
#  'mexican wave  #B64A32': 'background:#B64A32;',
#  'vivid red [2] #E70000': 'background:#E70000;',
#  'sienna [9] #9E6759': 'background:#9E6759;',
#  'desperado  #753929': 'background:#753929;',
#  'rufous  #A81C07': 'background:#A81C07;',
#  'mordant red  #AE0C00': 'background:#AE0C00;',
#  'mordant red 19  #AE0C00': 'background:#AE0C00;',
#  'tandoori  #8D4532': 'background:#8D4532;',
#  'tia maria [2] #97422D': 'background:#97422D;',
#  'mule fawn [2] #884F40': 'background:#884F40;',
#  'PMS485 2X  #CC0C00': 'background:#CC0C00;',
#  'PMS185 2X  #D11600': 'background:#D11600;',
#  'PMS485  #D81E05': 'background:#D81E05;',
#  'orang atan  #C54F33': 'background:#C54F33;',
#  'trinidad [2] #C54F33': 'background:#C54F33;',
#  'vivid scarlet  #E71D00': 'background:#E71D00;',
#  'felix  #534541': 'background:#534541;',
#  'warm kwila  #753A2A': 'background:#753A2A;',
#  'kobe  #882D17': 'background:#882D17;',
#  'strong scarlet  #A81500': 'background:#A81500;',
#  'nutmeg [3] #7E4A3B': 'background:#7E4A3B;',
#  'fire [2] #8F3F2A': 'background:#8F3F2A;',
#  'rock spray [2] #9D442D': 'background:#9D442D;',
#  'chinese red  #AA381E': 'background:#AA381E;',
#  'wild west  #9A5440': 'background:#9A5440;',
#  'blaze  #BE4123': 'background:#BE4123;',
#  'PMS1788 2X  #D62100': 'background:#D62100;',
#  'satin orange  #C64020': 'background:#C64020;',
#  'peanut [2] #7A4434': 'background:#7A4434;',
#  'burnt red  #9F2305': 'background:#9F2305;',
#  'krakatoa  #9D523B': 'background:#9D523B;',
#  'pueblo [2] #7D2C14': 'background:#7D2C14;',
#  'rust red  #AA2704': 'background:#AA2704;',
#  'spicy mix [2] #885342': 'background:#885342;',
#  'brown rust  #AF593E': 'background:#AF593E;',
#  'moderate vermilion  #A8614A': 'background:#A8614A;',
#  'luminous vivid raspberry  #FF0060': 'background:#FF0060;',
#  'PMS193  #DB828C': 'background:#DB828C;',
#  'dusty rose [2] #C0737A': 'background:#C0737A;',
#  'PMS191  #F4476B': 'background:#F4476B;',
#  'wild watermelon [2] #FD5B78': 'background:#FD5B78;',
#  'ruddy pink  #E18E96': 'background:#E18E96;',
#  'radical red [2] #FF496C': 'background:#FF496C;',
#  'froly [2] #F57584': 'background:#F57584;',
#  'opium [2] #8E6F70': 'background:#8E6F70;',
#  'PMS695  #B26B70': 'background:#B26B70;',
#  'PMS702  #D6606D': 'background:#D6606D;',
#  'dirty pink  #CA7B80': 'background:#CA7B80;',
#  'fiery rose  #FF5470': 'background:#FF5470;',
#  'PMS701  #E8878E': 'background:#E8878E;',
#  'PMS1775  #F9848E': 'background:#F9848E;',
#  'snow [4] #8B8989': 'background:#8B8989;',
#  'magic potion  #FF4466': 'background:#FF4466;',
#  'neon fuchsia [2] #FE4164': 'background:#FE4164;',
#  'PMS709  #F26877': 'background:#F26877;',
#  'PMS184  #FC5E72': 'background:#FC5E72;',
#  'light brilliant amaranth  #FF6578': 'background:#FF6578;',
#  'PMS500  #CE898C': 'background:#CE898C;',
#  'double rakaia  #A9A5A5': 'background:#A9A5A5;',
#  'blush pink [2] #FE828C': 'background:#FE828C;',
#  'PMS4995  #A56B6D': 'background:#A56B6D;',
#  'dark terra cotta  #CC4E5C': 'background:#CC4E5C;',
#  'pink red  #F5054F': 'background:#F5054F;',
#  'mandy [2] #E25465': 'background:#E25465;',
#  'brilliant amaranth  #E75164': 'background:#E75164;',
#  'candy pink [2] #E4717A': 'background:#E4717A;',
#  'tango pink  #E4717A': 'background:#E4717A;',
#  'PMS1777  #FC6675': 'background:#FC6675;',
#  'reddish grey [2] #A89C9C': 'background:#A89C9C;',
#  'dusty grey [2] #AC9B9B': 'background:#AC9B9B;',
#  'nobel [2] #A99D9D': 'background:#A99D9D;',
#  'amaranth  #E52B50': 'background:#E52B50;',
#  'bazaar [2] #8F7777': 'background:#8F7777;',
#  'PMS812 2X  #FC074F': 'background:#FC074F;',
#  'folly  #FF004F': 'background:#FF004F;',
#  'red pink  #FA2A55': 'background:#FA2A55;',
#  'grayish red  #A87D7D': 'background:#A87D7D;',
#  'old rose [2] #C08081': 'background:#C08081;',
#  'light carmine pink  #E66771': 'background:#E66771;',
#  'pink [9] #BC8F8F': 'background:#BC8F8F;',
#  'rosy brown [5] #BC8F8F': 'background:#BC8F8F;',
#  'rosybrown [4] #BC8F8F': 'background:#BC8F8F;',
#  'tuscany [3] #C09999': 'background:#C09999;',
#  'red [12] #EE204D': 'background:#EE204D;',
#  'awesome  #FF2052': 'background:#FF2052;',
#  'reddish pink  #FE2C54': 'background:#FE2C54;',
#  'PMS5005  #BC8787': 'background:#BC8787;',
#  'PMS694  #C98C8C': 'background:#C98C8C;',
#  'oriental pink [2] #C69191': 'background:#C69191;',
#  'coral tree [2] #A86B6B': 'background:#A86B6B;',
#  'desire  #EA3C53': 'background:#EA3C53;',
#  'material girl  #E85560': 'background:#E85560;',
#  'pinkish red  #F10C45': 'background:#F10C45;',
#  'PMS710  #E04251': 'background:#E04251;',
#  'foxtrot  #B6706F': 'background:#B6706F;',
#  'sizzling red  #FF3855': 'background:#FF3855;',
#  'watermelon  #FD4659': 'background:#FD4659;',
#  'fuzzy wuzzy  #CC6666': 'background:#CC6666;',
#  'fuzzy wuzzy brown [2] #CC6666': 'background:#CC6666;',
#  'coral light  #F08080': 'background:#F08080;',
#  'light coral  #F08080': 'background:#F08080;',
#  'salmon pink [2] #FE7B7C': 'background:#FE7B7C;',
#  'red ribbon  #ED0A3F': 'background:#ED0A3F;',
#  'chestnut [5] #CD5C5C': 'background:#CD5C5C;',
#  'chestnut rose  #CD5C5C': 'background:#CD5C5C;',
#  'indian red [8] #CD5C5C': 'background:#CD5C5C;',
#  'PMS1787  #F43F4F': 'background:#F43F4F;',
#  'pinky red  #FC2647': 'background:#FC2647;',
#  'scarlet [5] #FC2847': 'background:#FC2847;',
#  'lightish red  #FE2F4A': 'background:#FE2F4A;',
#  'PMS1785  #FC4F59': 'background:#FC4F59;',
#  'carnation [2] #F95A61': 'background:#F95A61;',
#  'sea pink [2] #DB817E': 'background:#DB817E;',
#  'faded red  #D3494E': 'background:#D3494E;',
#  'indianred [4] #CD5555': 'background:#CD5555;',
#  'hurricane [2] #877C7B': 'background:#877C7B;',
#  'american rose  #FF033E': 'background:#FF033E;',
#  'carmine [4] #FF0040': 'background:#FF0040;',
#  'electric crimson  #FF003F': 'background:#FF003F;',
#  'luminous vivid crimson  #FF0040': 'background:#FF0040;',
#  'coral pink [2] #FF6163': 'background:#FF6163;',
#  'new york pink [2] #D7837F': 'background:#D7837F;',
#  'PMS177  #F9827F': 'background:#F9827F;',
#  'mahogany [6] #CD4A4C': 'background:#CD4A4C;',
#  'strawberry [2] #FB2943': 'background:#FB2943;',
#  'adore  #CB6B67': 'background:#CB6B67;',
#  'red salsa  #FD3A4A': 'background:#FD3A4A;',
#  'roman [2] #DE6360': 'background:#DE6360;',
#  ...}

# %% [markdown]
# ## Time To Clean!
#
# Remove the `background:` from color values, lowercase them and also remove square brackets and weird colors altogether.

# %%
clean_colors = {}
for name, code in colors.items():
  name = name[:name.find('#')].strip()
  name = re.sub(r'[\[\]]', r'', name)

  if name.startswith('PMS'):
    continue  # skip weird colors

  if 'rgb=' in name:
    continue

  code = re.sub(
      r'background:\s?', 
      r'', 
      code.lower()
  )    

  if code.strip().startswith('#'):
    clean_colors[name] = code.strip().strip(';')

# %%
clean_colors
# Out:
# {'black 3': '#1e1e1e',
#  'grey 105': '#e3e3e3',
#  'merlot 3': '#73343a',
#  'tundora 2': '#585452',
#  'horoscope': '#43373a',
#  'wine 2': '#722f37',
#  'loyal': '#28191d',
#  'arthouse': '#4d202e',
#  'verve': '#5d2e3c',
#  'extrovert': '#752642',
#  'encore': '#54162c',
#  'siren 2': '#7a013a',
#  'black sheep': '#3e393a',
#  'spitfire': '#381921',
#  'black rose 2': '#532934',
#  'tempo': '#462b31',
#  'wine berry 2': '#591d35',
#  'dark crimson 2': '#592734',
#  'velocity': '#4b4042',
#  'double caffeine': '#332729',
#  'castro 2': '#44232f',
#  'temptress 2': '#3b000b',
#  'aubergine 3': '#3d0734',
#  'red earth': '#462028',
#  'ravishing': '#401a22',
#  'deep raspberry': '#590021',
#  'rendezvous': '#561426',
#  'afficionado': '#453638',
#  'double sidewinder': '#473f40',
#  'jumpstart': '#3e2025',
#  'chocolate 9': '#cd661d',
#  'persian red 3': '#cc3333',
#  'attitude': '#532b32',
#  'jon 2': '#3b1f1f',
#  'hot wired': '#6f2637',
#  'mayhem': '#4d1b25',
#  'burgundy 5': '#900020',
#  'livid brown 2': '#312a29',
#  'platypus': '#3d3334',
#  'cab sav 2': '#4d0a18',
#  'red letter': '#751631',
#  'claret 3': '#680018',
#  'bordeaux 3': '#5c0120',
#  'maroon 13': '#ee30a7',
#  'contraband': '#462429',
#  'red wine': '#8c0034',
#  'courage': '#4b252a',
#  'cowboy 2': '#443736',
#  'zibibbo': '#51242b',
#  'breakfree': '#65192a',
#  'night owl': '#483335',
#  'dark puce': '#4f3a3c',
#  'sidewinder': '#554d4f',
#  'violet red 9': '#ee3a8c',
#  'pale violet red 5': '#ff82ab',
#  'scrumptious': '#b71d62',
#  'cannon pink 2': '#894367',
#  'china rose': '#a8516e',
#  'red purple 2': '#820747',
#  'dark grayish crimson': '#594248',
#  'disco 2': '#871550',
#  'irresistible 2': '#b3446c',
#  'raspberry rose': '#b3446c',
#  'mauve taupe': '#915f6d',
#  'raspberry glace': '#915f6d',
#  'fuchsia rose': '#c74375',
#  'lipstick 3': '#ab0563',
#  'tickled pink': '#962c54',
#  'strong rose': '#a80054',
#  'rouge 3': '#a23b6c',
#  'berry': '#990f4b',
#  'filmpro magenta': '#aa305d',
#  'memory': '#7c5b63',
#  'cadillac 2': '#984961',
#  'rich maroon': '#b03060',
#  'cranberry 4': '#b6316c',
#  'pink panther': '#b43864',
#  'rose dust': '#9e5e6f',
#  'vin rouge 2': '#983d61',
#  'deep pink 5': '#ee1289',
#  'pink 9': '#ff81c0',
#  'blush 4': '#f29e8e',
#  'purple red': '#990147',
#  'colour me pink': '#a90c50',
#  'dogwood rose': '#d71868',
#  'dark hot pink': '#d90166',
#  'empress 2': '#817377',
#  'mortar 2': '#504351',
#  'don juan 2': '#5d4c51',
#  'brownish purple': '#76424e',
#  'renaissance': '#885a64',
#  'night shadz 2': '#aa375a',
#  'dark pink 2': '#e75480',
#  'emperor 2': '#514649',
#  'galaxy': '#63464b',
#  'camelot 2': '#893456',
#  'zambezi 2': '#6b5a5a',
#  'moderate crimson': '#a84a61',
#  'hippie pink 2': '#ae4560',
#  'jazzberry jam 2': '#a50b5e',
#  'spicy pink 3': '#ff1cae',
#  'catawba': '#703642',
#  'purplish red': '#b0054b',
#  'light burgundy': '#a8415b',
#  'cerise 4': '#dd4492',
#  'matchmaker': '#6d3540',
#  'raspberry 5': '#872657',
#  'amaranth deep purple': '#ab274f',
#  'amaranth purple': '#ab274f',
#  'rose red 2': '#be013c',
#  'eighth barista': '#746466',
#  'deep rose 2': '#59002d',
#  'rubine red': '#d10056',
#  'ruby 2': '#ca0147',
#  'geronimo': '#88213c',
#  'sensual red': '#902742',
#  'pictorial carmine': '#c30b4e',
#  'hibiscus 2': '#b6316c',
#  'light pink 7': '#ffd1df',
#  'deep puce': '#a95c68',
#  'razzmatazz 2': '#e3256b',
#  'satellite': '#554244',
#  'rosehip': '#842139',
#  'purplish brown': '#6b4247',
#  'spellbound': '#6d4a4e',
#  'sargent pepper': '#a34053',
#  'dark rose 2': '#592740',
#  'miss hussy': '#c44762',
#  'strong raspberry': '#a8003f',
#  'big dip o ruby': '#9c2542',
#  'light maroon': '#a24857',
#  'debian red': '#d70a53',
#  'popstar 2': '#be4e62',
#  'tapestry 2': '#b05e81',
#  'medium pink 5': '#cd6490',
#  'mystic 3': '#e2ebed',
#  'fandango pink': '#de5285',
#  'cerise pink': '#ec3b83',
#  'brilliant raspberry': '#e75189',
#  'medium violet red 2': '#c71585',
#  'pale red violet': '#db7093',
#  'violet red pale': '#db7093',
#  'dull pink': '#d5869d',
#  'french pink': '#fd6c9e',
#  'can 2': '#d591a4',
#  'vivid rose': '#e70074',
#  'darkish pink': '#da467d',
#  'grayish crimson': '#a87d88',
#  'french rose': '#f64a8a',
#  'deep blush 2': '#e47698',
#  'viola 2': '#cb8fa9',
#  'carnation pink 3': '#ffaacc',
#  'ruber': '#ce4676',
#  'mauve 2': '#e0b0ff',
#  'bright pink 2': '#fe01b1',
#  'luminous vivid rose': '#ff0080',
#  'rose 4': '#e7bcb4',
#  'muted pink': '#d1768f',
#  'puce 2': '#a57e52',
#  'tickle me pink 2': '#fc89ac',
#  'winter sky': '#ff007c',
#  'light crimson 2': '#e78ba2',
#  'pig pink 2': '#fdd7e4',
#  'cinnamon satin': '#cd607e',
#  'high tea': '#a18c90',
#  'charm 2': '#d47494',
#  'strawberry 2': '#fb2943',
#  'dusty grey 2': '#ac9b9b',
#  'grey pink': '#c3909b',
#  'turkish rose 2': '#b57281',
#  'vintage': '#a78087',
#  'rosy pink': '#f6688e',
#  'minnelli': '#b16b79',
#  'cabaret 2': '#d94972',
#  'sasquatch socks': '#ff4681',
#  'dusky pink 2': '#927571',
#  'light brilliant crimson': '#ff658b',
#  'shimmering blush': '#d98695',
#  'carissma 2': '#ea88a8',
#  'brilliant crimson': '#e75177',
#  'wisteria 5': '#c9a0dc',
#  'anticipation': '#a88a8e',
#  'warm pink': '#fb5581',
#  'bona fide': '#97777b',
#  'bazaar 2': '#8f7777',
#  'vivid raspberry 2': '#e70057',
#  'pinkish': '#d46a7e',
#  'old pink': '#c77986',
#  'ugly pink': '#cd7584',
#  'careys pink 2': '#d29eaa',
#  'cerise red': '#de3163',
#  'cherry 2': '#cf0234',
#  'rocket metallic': '#8a7f80',
#  'rose gold': '#b76e79',
#  'old rose 2': '#c08081',
#  'tonto': '#9f9596',
#  'dusty pink': '#d58a94',
#  'rose pink 2': '#ff66cc',
#  'brink pink': '#fb607f',
#  'greyish pink': '#c88d94',
#  'glamour puss': '#f8748b',
#  'carnation 2': '#f95a61',
#  'dusky rose': '#ba6873',
#  'ultra red': '#fc6c85',
#  'wild watermelon 2': '#fd5b78',
#  'light amaranth': '#e78b96',
#  'melanie 2': '#e4c2d5',
#  'cupid 2': '#fbbeda',
#  'pink lace 2': '#ffddf4',
#  'pale light grayish crimson': '#e7b8c4',
#  'pastel pink 3': '#dea5a4',
#  'pinky': '#fc86aa',
#  'illusion 2': '#f6a4c9',
#  'pink swan 2': '#bfb3b2',
#  'pink flare 2': '#d8b4b6',
#  'pale crimson': '#ffc2d1',
#  'vanilla ice 3': '#ebd2d1',
#  'baker miller pink': '#ff91af',
#  'schauss pink': '#ff91af',
#  'faded pink': '#de9dac',
#  'mauvelous 2': '#f091a9',
#  'flamingo pink': '#fc8eac',
#  'boutique': '#dfacb7',
#  'very light crimson': '#ff9eb6',
#  'black shadows': '#bfafb2',
#  'blossom 2': '#dcb4bc',
#  'gelato': '#dbb7be',
#  'rosa': '#fe86a4',
#  'pink sherbet': '#f78fa7',
#  'soft pink 2': '#f2cdbb',
#  'cherry blossom pink': '#ffb7c5',
#  'pale rose 4': '#ffc2e0',
#  'pretty in pink': '#efd6da',
#  'cherub 2': '#f8d9e9',
#  'bubble gum': '#ffc1cc',
#  'floyd': '#da9ca6',
#  'wewak 2': '#f1919a',
#  'pink light': '#ffb6c1',
#  'pink salmon': '#ff91a4',
#  'salmon pink 2': '#fe7b7c',
#  'devoted': '#e8cdd0',
#  'salmon 8': '#ff8c69',
#  'kidman': '#ccb7b9',
#  'pale amaranth': '#ffc2c9',
#  'light rose 2': '#e78bb9',
#  'very light amaranth': '#ff9eaa',
#  'very pale crimson': '#ffe2e9',
#  'bon jour 2': '#dfd7d2',
#  'carousel pink 2': '#f9e0ed',
#  'pale pink 4': '#ffaac8',
#  'diesel 2': '#322c2b',
#  'very deep reddish brown': '#1d0000',
#  'very reddish brown': '#1d1111',
#  'charcoal 3': '#36454f',
#  'sepia 6': '#a5694f',
#  'sepia black': '#2b0202',
#  'toast lmu 15': '#2a0f10',
#  'dark maroon': '#3c0008',
#  'gondola 2': '#373332',
#  'very dark brown 2': '#5c4033',
#  'beer srm 40': '#35090a',
#  'beer srm 38': '#390708',
#  'licorice 3': '#092256',
#  'night rider 2': '#332e2e',
#  'kilamanjaro 2': '#3a3532',
#  'coffee bean 2': '#362d26',
#  'cuban tan 2': '#362d26',
#  'marlin 2': '#362d26',
#  'blackwood 2': '#3f372e',
#  'wood bark 2': '#302621',
#  'x factor': '#681b2b',
#  'havana 2': '#3b2b2c',
#  'jarrah 2': '#3b2b2c',
#  'speed demon': '#551b24',
#  'dark amaranth': '#59272d',
#  'vanquish': '#63272f',
#  'i c red': '#7a2031',
#  'dark scarlet 2': '#560319',
#  'bulgarian rose 2': '#482427',
#  'puce red': '#722f37',
#  'renegade': '#592228',
#  'avant garde': '#5c2c30',
#  'windswept': '#434141',
#  'reddish brownish black': '#1d1a1a',
#  'double barbecue': '#282020',
#  'maxwell smart': '#2a2525',
#  'red baron': '#511d22',
#  'sheer black': '#332f2f',
#  'barbecue': '#363030',
#  'half bokara grey': '#353333',
#  'half diesel': '#353131',
#  'lava 2': '#cf1020',
#  'heath 2': '#4f2a2c',
#  'pohutukawa 2': '#651c26',
#  'style pasifika hibiscus blood': '#651c26',
#  'eclipse 2': '#3f3939',
#  'salsa': '#770c25',
#  'rustic red 2': '#3a181a',
#  'deep crimson': '#590016',
#  'cave rock': '#372c2c',
#  'madam m': '#610c1d',
#  'livewire': '#6d1c27',
#  'jazz 2': '#5f2c2f',
#  'jalapeno': '#701c28',
#  'wine red': '#7b0323',
#  'hot chile 2': '#6b252c',
#  'monarch 2': '#6b252c',
#  'western red 2': '#6b252c',
#  'half barista': '#513f3f',
#  'scarlett 2': '#950015',
#  'antique ruby': '#841b2d',
#  'maroon oak': '#520c17',
#  'crater brown 2': '#462425',
#  'style pasifika red soil': '#4e2728',
#  'volcano 2': '#4e2728',
#  'lonestar 2': '#522426',
#  'woody brown 2': '#554545',
#  'razzamatazz': '#701f28',
#  'red berry 2': '#701f28',
#  'earlybird': '#513939',
#  'code red': '#880025',
#  'beer srm 39': '#39080b',
#  'burnt crimson 2': '#582124',
#  'indian red 8': '#cd5c5c',
#  'buccaneer 2': '#6e5150',
#  'congo brown 2': '#654d49',
#  'paprika 2': '#7c2d37',
#  'venetian red 4': '#d41a1f',
#  'red devil 2': '#662a2c',
#  'japanese maple 2': '#672f30',
#  'tamarillo 2': '#991613',
#  'bullseye': '#7d222b',
#  'seal brown': '#321414',
#  'tamarind 2': '#341515',
#  'nelson red': '#4f2525',
#  'deep impact': '#672729',
#  'dark tan 5': '#af884a',
#  'red ochre': '#612d2d',
#  'dynamite': '#6f282b',
#  'cocoa brown 3': '#d2691e',
#  'cocoa bean 2': '#481c1c',
#  'mahogany 6': '#c04000',
#  'filmpro burnt sienna': '#522c2b',
#  'reddish brown 2': '#7f2b0a',
#  'burnt sienna 5': '#8a360f',
#  'persian plum 2': '#683332',
#  'toast lmu 20': '#380a08',
#  'dark sienna': '#3c1414',
#  'rialto': '#4c2322',
#  'jarrah tree': '#52312f',
#  'barista': '#453837',
#  'coco': '#682828',
#  'beer srm 37': '#3c0908',
#  'burnt maroon': '#420303',
#  'patio red': '#6d3331',
#  'deep brown 2': '#592d00',
#  'beer srm 36': '#420807',
#  'deep amaranth': '#59000b',
#  'toorak': '#392523',
#  'old burgundy': '#43302e',
#  'rata': '#5d1f1e',
#  'red oxide 2': '#5d1f1e',
#  'fahrenheit': '#672e2b',
#  'beer srm 35': '#440705',
#  'stingray': '#453533',
#  'cherrywood 2': '#4e312e',
#  'cajun': '#662f2b',
#  'kenyan copper 2': '#6c322e',
#  'beer srm 34': '#4a0605',
#  'dried blood': '#4b0101',
#  'rosewood 2': '#8f3e3f',
#  'moccaccino 2': '#582f2b',
#  'hot n spicy': '#6b2320',
#  'prune': '#701c1c',
#  'van cleef 2': '#523936',
#  'crown of thorns 2': '#763c33',
#  'espresso 2': '#4e312d',
#  'beer srm 33': '#500b08',
#  'style pasifika burnt charcoal': '#322c2b',
#  'double barista': '#392c2a',
#  'pioneer red': '#642620',
#  'echo': '#483c3a',
#  'heatwave': '#6e2620',
#  'falu red': '#801818',
#  'deep reddish brown': '#590000',
#  'style pasifika black tan': '#3a2f2d',
#  'scoria': '#532620',
#  'barn red 2': '#602821',
#  'tipping point': '#612c25',
#  'redwood 3': '#a45a52',
#  'red sienna': '#5f312a',
#  'up maroon': '#7b1113',
#  'kakaramea': '#6e2c25',
#  'crimson 2': '#dc143c',
#  'bean 2': '#3d0c02',
#  'black bean 3': '#232e26',
#  'beer srm 32': '#530b06',
#  'hot chocolate': '#3d2622',
#  'digeridoo': '#452924',
#  'style pasifika brown earth': '#452924',
#  'hinau': '#482a25',
#  'red planet': '#5a2019',
#  'hukanui': '#572a23',
#  'caput mortuum': '#592720',
#  'kwila': '#6d332a',
#  'warmed brown': '#4a302b',
#  'jarrah stain': '#57332c',
#  'toast lmu 25': '#49140b',
#  'beer srm 31': '#560c03',
#  'blood': '#770001',
#  'cedar 3': '#463430',
#  'rattlesnake': '#463835',
#  'oiled cedar 2': '#66362d',
#  'meranti 2': '#6b342a',
#  'deep scarlet': '#590b00',
#  'beer srm 30': '#5b0d03',
#  'rebel 2': '#453430',
#  'pepperwood': '#542f27',
#  'rock 2': '#5a4d41',
#  'web maroon': '#800000',
#  'triple lumberjack': '#5a372f',
#  'metallic copper 2': '#6e3d34',
#  'beer srm 29': '#620f03',
#  'beer srm 28': '#671003',
#  'reddy brown': '#6e1005',
#  'dark burgundy': '#770f05',
#  'deep maroon': '#820000',
#  'dark red 2': '#840000',
#  'deep red 2': '#9a0200',
#  'komakorau': '#64352a',
#  'red 12': '#ee204d',
#  'pueblo 2': '#7d2c14',
#  'french puce': '#4e1609',
#  'short black': '#42231b',
#  'dark liver 2': '#534b4f',
#  'dark oak 2': '#55342b',
#  'liver 4': '#534b4f',
#  'beer srm 27': '#6c1603',
#  'hairy heath 2': '#6b2a14',
#  'dark ginger': '#473029',
#  'mocha 3': '#9d7651',
#  'deep vermilion': '#591600',
#  'baked earth': '#493028',
#  'cedar wood finish': '#711a00',
#  'beer srm 25': '#771c01',
#  'purple brown': '#673a3f',
#  'ribbon 2': '#660045',
#  'pink raspberry': '#980036',
#  'french wine': '#ac1e44',
#  'lollipop': '#7f2838',
#  'erotic': '#94414c',
#  'deep taupe': '#7e5e60',
#  'dingy dungeon': '#c53151',
#  'filmpro deep red': '#90243a',
#  'solid pink 2': '#893843',
#  'falcon 2': '#7f626d',
#  'ua red': '#d9004c',
#  'candy floss': '#9f263d',
#  'deep carmine': '#a9203e',
#  'bright maroon': '#c32148',
#  'maroon flush': '#c32148',
#  'moderate amaranth': '#a84a55',
#  'spanish carmine': '#d10047',
#  'ferra 2': '#704f50',
#  'dove grey 2': '#777672',
#  'brunette': '#634041',
#  'solar flare': '#693e40',
#  'matterhorn 2': '#4e3b41',
#  'rock n roll': '#9d002f',
#  'reddish brownish grey': '#595353',
#  'cordovan': '#893f45',
#  'identity': '#6e6767',
#  'french raspberry': '#c72c48',
#  'weathered grey': '#776f6f',
#  'brick red 3': '#cb4154',
#  'spanish crimson': '#e51a4c',
#  'dark grayish reddish brown': '#594242',
#  'shiraz 2': '#842833',
#  'tosca 2': '#744042',
#  'quarter barista': '#614f4f',
#  'vivid burgundy': '#9f1d35',
#  'zinger': '#873d42',
#  'vibe': '#ac3142',
#  'la bamba': '#a43f48',
#  'knock out': '#c81641',
#  'dusty rose 2': '#c0737a',
#  'english red 2': '#ab4b52',
#  'rosy brown 5': '#eeb4b4',
#  'rosybrown 4': '#eeb4b4',
#  'fast lane': '#892431',
#  'crash hot': '#af2e40',
#  'rose taupe': '#905d5d',
#  'utah crimson': '#d3003f',
#  'carmine 4': '#ff0040',
#  'rich carmine': '#d70040',
#  'copper rose': '#996666',
#  'sangria 2': '#822a32',
#  'adrenalin junkie': '#7f3136',
#  'pirate': '#902f37',
#  'crossroads': '#734949',
#  'tuscan red 2': '#66424d',
#  'cha': '#8c3f42',
#  'hot stuff': '#874748',
#  'orbit': '#874748',
#  'smokey topaz': '#933d41',
#  'smoky topaz': '#933d41',
#  'bombshell': '#ae2f3e',
#  'rose vale': '#ab4e52',
#  'permanent red violet': '#db2645',
#  'stiletto 2': '#833d3e',
#  'roadster': '#9f2c37',
#  'red tape': '#b3002f',
#  'filmpro fire red': '#a5333c',
#  'crimson glory': '#be0032',
#  'cardinal 3': '#8c055e',
#  'dusty red': '#b9484e',
#  'memphis belle': '#ca2f43',
#  'flame red 2': '#86282e',
#  'monza 2': '#86282e',
#  'rocket': '#86282e',
#  'deep coffee': '#704241',
#  'roast coffee': '#704241',
#  'xotic': '#863336',
#  'strong crimson': '#a8002a',
#  'japanese carmine': '#9d2933',
#  'glitterbug': '#a92a37',
#  'copper rust 2': '#944747',
#  'aphrodisiac': '#a64d4e',
#  'warhol': '#9b615f',
#  'rusty red 2': '#da2c43',
#  'sanguine brown 2': '#6c3736',
#  'old brick 2': '#8a3335',
#  'bright red 3': '#ff000d',
#  'chaos': '#922a31',
#  'vermilion 4': '#ff4d00',
#  'lotus 2': '#863c3c',
#  'well read 2': '#8e3537',
#  'red hot': '#952b32',
#  'alabama crimson': '#af002a',
#  'punch 2': '#dc4333',
#  'lipstick red': '#c0022f',
#  'vivid crimson 2': '#cc0033',
#  'moderate red': '#a84a4a',
#  'quickstep': '#a7615f',
#  'bittersweet shimmer': '#bf4f51',
#  'rose ebony': '#674846',
#  'flash point': '#932c31',
#  'indianred 4': '#cd5555',
#  'mexican red 2': '#9b3d3d',
#  'terracotta pink': '#9b3d3d',
#  'ameile': '#904947',
#  'bliss': '#b3393e',
#  'au chico 2': '#97605d',
#  'tall poppy 2': '#853534',
#  'guardsman red 2': '#952e31',
#  'dorado 2': '#6e5f56',
#  'hot spot': '#b22833',
#  'cincinnati': '#a5403f',
#  'get reddy': '#ad3539',
#  'havoc': '#ad3539',
#  'lusty 2': '#782e2c',
#  'brown 11': '#b4674d',
#  'intrigue': '#814743',
#  'red pepper': '#bb112a',
#  'roof terracotta 2': '#a14743',
#  'alter ego': '#ab4c48',
#  'dull red': '#bb3f3f',
#  'pharlap 2': '#a3807b',
#  'style pasifika red frangipani': '#832b29',
#  'totem pole 2': '#883531',
#  'tabasco 2': '#8e3a36',
#  'smashing': '#ad0020',
#  'wenge': '#645452',
#  'afterburner': '#983d39',
#  'style pasifika red pineapple': '#983d39',
#  'milano red 2': '#9e3332',
#  'upsdell red': '#ae2029',
#  'russett 2': '#7d655c',
#  'reddish': '#c44240',
#  'geranium lake': '#e31230',
#  'jasper 2': '#4e6590',
#  'alizarin crimson': '#e32636',
#  'rose madder 2': '#e33638',
#  'ruby red': '#9b111e',
#  'forbidden': '#b04640',
#  'flush mahogany': '#ca3435',
#  'chestnut 5': '#742802',
#  'deep chestnut': '#b94e48',
#  'medium candy apple red': '#e2062c',
#  'sunset 3': '#fad6a5',
#  'raging bull': '#7f2f2a',
#  'erica': '#81332d',
#  'firebrick 6': '#ee2c2c',
#  'auburn 2': '#9a3001',
#  'red brown 2': '#a52a2a',
#  'fusion': '#98463e',
#  'kachow': '#a23a34',
#  'whizz bang': '#a23a34',
#  'moulin rouge': '#ad463f',
#  'quarter felix': '#746765',
#  'apple blossom 2': '#a95249',
#  'amaranth red': '#d3212d',
#  'matrix 2': '#b05d54',
#  'mustang': '#7f352e',
#  'vivid auburn': '#922724',
#  'roller coaster': '#923830',
#  'thunderbird 2': '#923830',
#  'poppy': '#ac0019',
#  'sweet brown': '#a83731',
#  'el salva 2': '#8f4e45',
#  'cognac 2': '#9a463d',
#  'fire engine red 2': '#fe0002',
#  'flair': '#b94b42',
#  'bring it on': '#c3423b',
#  'spanish red': '#e60026',
#  "giant's club": '#b05c52',
#  'scarlet 5': '#fc2847',
#  'vixen': '#81342b',
#  'sunspot': '#7e372e',
#  'crab apple 2': '#87382f',
#  'red robin 2': '#7d4138',
#  'strong amaranth': '#a80015',
#  'artefact': '#5d5250',
#  'del toro': '#b11d20',
#  'mojo 2': '#97463c',
#  'hot august': '#9a463b',
#  'half lumberjack': '#845a53',
#  'medium carmine': '#af4035',
#  'pale carmine': '#af4035',
#  'moderate scarlet': '#a8554a',
#  'promise': '#936962',
#  'brown madder': '#db2929',
#  'cadmium red': '#e30022',
#  'permanent geranium lake': '#e12c2c',
#  'lexington': '#683e37',
#  'spartan crimson': '#9e1316',
#  'medium taupe': '#674c47',
#  'bole': '#79443b',
#  'medium tuscan red': '#79443b',
#  'prairie sand 2': '#883c32',
#  'cracker': '#963128',
#  'carnelian': '#b31b1b',
#  'cornell red': '#b31b1b',
#  'international orange 3': '#ff4f00',
#  'vivid amaranth': '#e7001d',
#  'daredevil': '#cb483b',
#  'tomahawk': '#524340',
#  'pulse': '#a41d19',
#  'bonfire': '#a62a20',
#  'harvard crimson': '#c90016',
#  'crail 2': '#a65648',
#  'dark chestnut': '#986960',
#  'lust': '#e62020',
#  'dawnbreaker': '#813125',
#  'lumberjack': '#724b43',
#  'rust 3': '#b7410e',
#  'ironstone 2': '#86483c',
#  'kamikaze': '#a43f30',
#  'pursuit': '#d9251d',
#  'double lumberjack': '#633e36',
#  'western red cedar': '#7a372a',
#  'burnt umber 3': '#a0450e',
#  'darkish red': '#a90308',
#  'coral 9': '#c0b093',
#  'embers 2': '#8c3f30',
#  'copper fire': '#925345',
#  'ku crimson': '#e8000d',
#  'oh behave': '#be523f',
#  'clementine 2': '#e96e00',
#  'blood red': '#980002',
#  'tomato 5': '#cd4f39',
#  'copperhead': '#755148',
#  'brick 2': '#9c661f',
#  'brownish red': '#9e3623',
#  'balloon': '#c14d36',
#  'grenadier 2': '#d54600',
#  'cadmium red deep': '#e3170d',
#  'crimson red': '#990000',
#  'ou crimson red': '#990000',
#  'stizza': '#990000',
#  'usc cardinal': '#990000',
#  'teranova': '#7a3a2b',
#  'rough n tumble': '#5b4c48',
#  'scorched clay': '#7e3c2d',
#  'countdown': '#922f1d',
#  'dark candy apple red': '#a40000',
#  'strong red': '#a80000',
#  'boston university red': '#cc0000',
#  'rosso corsa': '#d40000',
#  'dark pastel red': '#c23b22',
#  'mexican wave': '#b64a32',
#  'vivid red 2': '#f70d1a',
#  'sienna 9': '#8e6b23',
#  'desperado': '#753929',
#  'rufous': '#a81c07',
#  'mordant red': '#ae0c00',
#  'mordant red 19': '#ae0c00',
#  'tandoori': '#8d4532',
#  'tia maria 2': '#c1440e',
#  'mule fawn 2': '#8c472f',
#  'orang atan': '#c54f33',
#  'trinidad 2': '#e64e03',
#  'vivid scarlet': '#e71d00',
#  'felix': '#534541',
#  'warm kwila': '#753a2a',
#  'kobe': '#882d17',
#  'strong scarlet': '#a81500',
#  'nutmeg 3': '#81422c',
#  'fire 2': '#aa4203',
#  'rock spray 2': '#ba450c',
#  'chinese red': '#aa381e',
#  'wild west': '#9a5440',
#  'blaze': '#be4123',
#  'satin orange': '#c64020',
#  'peanut 2': '#782f16',
#  'burnt red': '#9f2305',
#  'krakatoa': '#9d523b',
#  'rust red': '#aa2704',
#  'spicy mix 2': '#8b5f4d',
#  'brown rust': '#af593e',
#  'moderate vermilion': '#a8614a',
#  'luminous vivid raspberry': '#ff0060',
#  'ruddy pink': '#e18e96',
#  'radical red 2': '#ff496c',
#  'froly 2': '#f57584',
#  'opium 2': '#8e6f70',
#  'dirty pink': '#ca7b80',
#  'fiery rose': '#ff5470',
#  'snow 4': '#eee9e9',
#  'magic potion': '#ff4466',
#  'neon fuchsia 2': '#fe59c2',
#  'light brilliant amaranth': '#ff6578',
#  'double rakaia': '#a9a5a5',
#  'blush pink 2': '#ff6fff',
#  'dark terra cotta': '#cc4e5c',
#  'pink red': '#f5054f',
#  'mandy 2': '#e25465',
#  'brilliant amaranth': '#e75164',
#  'candy pink 2': '#ff63e9',
#  'tango pink': '#e4717a',
#  'reddish grey 2': '#a89c9c',
#  'nobel 2': '#b7b1b1',
#  'amaranth': '#e52b50',
#  'folly': '#ff004f',
#  'red pink': '#fa2a55',
#  'grayish red': '#a87d7d',
#  'light carmine pink': '#e66771',
#  'tuscany 3': '#ad6242',
#  'awesome': '#ff2052',
#  'reddish pink': '#fe2c54',
#  'oriental pink 2': '#c69191',
#  'coral tree 2': '#a86b6b',
#  'desire': '#ea3c53',
#  'material girl': '#e85560',
#  'pinkish red': '#f10c45',
#  'foxtrot': '#b6706f',
#  'sizzling red': '#ff3855',
#  'watermelon': '#fd4659',
#  'fuzzy wuzzy': '#cc6666',
#  'fuzzy wuzzy brown 2': '#cc6666',
#  'coral light': '#f08080',
#  'light coral': '#f08080',
#  'red ribbon': '#ed0a3f',
#  'chestnut rose': '#cd5c5c',
#  'pinky red': '#fc2647',
#  'lightish red': '#fe2f4a',
#  'sea pink 2': '#ed989e',
#  'faded red': '#d3494e',
#  'hurricane 2': '#8b7e77',
#  'american rose': '#ff033e',
#  'electric crimson': '#ff003f',
#  'luminous vivid crimson': '#ff0040',
#  'coral pink 2': '#ff6163',
#  'new york pink 2': '#d7837f',
#  'adore': '#cb6b67',
#  'red salsa': '#fd3a4a',
#  'roman 2': '#de6360',
#  'sunburnt cyclops': '#ff404c',
#  'sunglo 2': '#e16865',
#  'brownish pink': '#c27e79',
#  'light brilliant red 2': '#ff6565',
#  'geraldine 2': '#fb8989',
#  'neon red': '#ff073a',
#  'carmine red': '#ff0038',
#  'pastel red 2': '#db5856',
#  'dry creek': '#9a7f7c',
#  'brilliant red': '#e75151',
#  'rapture': '#f6484c',
#  'glorious': '#f07771',
#  'petite orchid 2': '#db9690',
#  'kubrick': '#8e7471',
#  'dark coral 2': '#cf524e',
#  'imperial red': '#ed2939',
#  'copper penny': '#ad6f69',
#  'torch red': '#fd0e35',
#  'tractor red': '#fd0e35',
#  'cheeky': '#cc5f59',
#  'contessa 2': '#c16f68',
#  'light red': '#ff474c',
#  'grapefruit': '#fd5956',
#  'brandy rose 2': '#bb8983',
#  'quarter lumberjack': '#96706b',
#  'dark salmon 2': '#e9967a',
#  'jive': '#cd5851',
#  'misty rose 4': '#ffe4e1',
#  'mistyrose 4': '#ffe4e1',
#  'pale red': '#d9544d',
#  'martini 2': '#b7a8a3',
#  'congo pink': '#f88379',
#  'tea rose 2': '#f4c2c2',
#  'valencia 2': '#d4574e',
#  'deep carmine pink': '#ef3038',
#  'coral red': '#ff4040',
#  'my pink 2': '#d69188',
#  'madder lake deep': '#e32e30',
#  'cherry red': '#f7022a',
#  'hemp 2': '#987d73',
#  'burnished brown': '#a17a74',
#  'tart orange': '#fb4d46',
#  'sunset orange 2': '#fd5e53',
#  'bittersweet 3': '#c29a4d',
#  'ruddy': '#ff0028',
#  'carmine pink': '#eb4c42',
#  'red orange 3': '#ff5349',
#  'thatch 2': '#b1948f',
#  'trubridge red': '#ed3c34',
#  'luminous vivid amaranth': '#ff0020',
#  'tom': '#92827f',
#  'light brilliant scarlet': '#ff7865',
#  'catalyst': '#c85241',
#  'cg red': '#e03c31',
#  'cedar chest': '#c95a49',
#  'cinnabar': '#e34234',
#  'suva grey 2': '#888387',
#  'jelly bean 3': '#44798e',
#  'quarter buffalo': '#998682',
#  'brilliant scarlet': '#e76451',
#  'ogre odor': '#fd5240',
#  'filmpro orange': '#d4503c',
#  'flamingo 2': '#e1634f',
#  'big bang': '#ff503c',
#  'persimmon 3': '#ec5800',
#  'sticky fingers': '#ef735e',
#  'flame pea 2': '#be5c48',
#  'eighth felix': '#897c79',
#  'terra cotta 2': '#c9643b',
#  'terracotta 2': '#ca6641',
#  'del rio 2': '#b5998e',
#  'quicksand 2': '#bd978e',
#  'double milestone': '#b1a09c',
#  'eighth buffalo': '#b1a09c',
#  'blast off bronze': '#a57164',
#  'cadmium red light': '#ff030d',
#  'triple milestone': '#a59591',
#  'orange pink': '#ff6f52',
#  'candy apple red': '#ff0800',
#  'luminous vivid red': '#ff0000',
#  'cinereous': '#98817b',
#  'orangey red': '#fa4224',
#  'bonanza': '#b77d6e',
#  'orange soda': '#fa5b3d',
#  'asteroid': '#a59692',
#  'hazy lavender': '#a49591',
#  'pinkish brown': '#b17261',
#  'luminous vivid scarlet': '#ff2000',
#  'orange red 6': '#ff4500',
#  'japonica 2': '#ce7259',
#  'portland orange': '#ff5a36',
#  'outrageous orange 2': '#ff6e4a',
#  'toast 2': '#9f715f',
#  'vermillion': '#f4320c',
#  'joie de vivre': '#cf6548',
#  'ferrari red': '#ff2800',
#  'pomegranate': '#f34723',
#  'triple rakaia': '#a19a98',
#  'pinkish orange': '#ff724c',
#  'melon 4': '#e3a869',
#  'half buffalo': '#89756f',
#  'tomato red': '#ec2d01',
#  'orangish red': '#f43605',
#  'copper red': '#cb6d51',
#  'reddish orange': '#f8481c',
#  'greenish umber': '#ff3d0d',
#  'light red ochre': '#e97451',
#  'fireball': '#cc5c39',
#  'medium vermilion': '#d9603b',
#  'coquelicot': '#ff3800',
#  'orangered': '#fe420f',
#  'sebedee': '#e96139',
#  'mamma mia': '#d5a4a8',
#  'azalea 2': '#f7c8da',
#  'pale chestnut': '#ddadaf',
#  'we peep 2': '#f7dbe6',
#  'cold turkey 2': '#cebaba',
#  'sundown 2': '#ffb1b3',
#  'pinkish grey 2': '#e7dada',
#  'tulip': '#ff878d',
#  'sweet pink 2': '#fd9fa2',
#  'pale grayish pink': '#e7b8b8',
#  'sweet spot': '#eab7b7',
#  'cavern pink 2': '#e3bebe',
#  'baby pink 2': '#ffb7ce',
#  'light salmon pink': '#ff9999',
#  'spanish pink': '#f7bfbe',
#  'oyster pink 2': '#e9cecd',
#  'silver pink': '#c4aead',
#  'paper doll': '#dfafad',
#  'your pink 2': '#ffc3c0',
#  'cherish': '#c6aba9',
#  'cornflower 6': '#6a79f7',
#  'cornflower lilac': '#ffb0ac',
#  'beauty bush 2': '#eec1be',
#  'bambina': '#e9d5d3',
#  'sweet as': '#dbb8b4',
#  'dust storm 2': '#e5cac0',
#  'eunry 2': '#cfa39d',
#  'shilo 2': '#e8b9b3',
#  'alto 2': '#dbdbdb',
#  'pale scarlet': '#ffc9c2',
#  'swiss coffee 2': '#dbd0ca',
#  'light scarlet': '#e7968b',
#  'cosmos 2': '#ffd8d9',
#  'mona lisa 2': '#ffa194',
#  'very light scarlet': '#ffaa9e',
#  'peachy pink': '#ff9a8a',
#  'rose fog': '#e7bcb4',
#  'coral candy 2': '#ffdcd6',
#  'pink terrace': '#f5d1ca',
#  'rose bud 2': '#feab9a',
#  'clam shell 2': '#d4b6af',
#  'half milestone': '#d1c4c1',
#  'vivid tangerine 2': '#ffa089',
#  'soulmate': '#cdb5af',
#  'urbane': '#d9d1cf',
#  'tonys pink 2': '#e79f8c',
#  'light salmon 5': '#ee9572',
#  'wafer 2': '#d4bbb1',
#  'sakura': '#e9b7a9',
#  'blanched pink': '#d0bbb5',
#  'pale salmon': '#ffb19a',
#  'ebb 2': '#e9e3e3',
#  'cinderella 2': '#fde1dc',
#  'light brilliant vermilion': '#ff8b65',
#  'birthday suit': '#d4a798',
#  'light vermilion': '#e7a28b',
#  'very light vermilion': '#ffb69e',
#  'pale vermilion': '#ffd1c2',
#  'hint of red 3': '#f9f9f9',
#  'whisper 2': '#f7f5fa',
#  'very pale pink': '#ffe2e2',
#  'pinkish white': '#fff6f6',
#  'tutu 2': '#fff1f9',
#  'soft peach 2': '#f5edef',
#  'pippin 2': '#ffe1df',
#  'chablis 2': '#fde9e0',
#  'rose white 2': '#fbeee8',
#  'remy 2': '#feebf3',
#  'chardon 2': '#f8eadf',
#  'peach schnapps 2': '#c68059',
#  'very light pink': '#fff4f2',
#  'fair pink 2': '#f3e5dc',
#  'sauvignon 2': '#f4eae4',
#  'forget me not 2': '#fdefdb',
#  'bizarre 2': '#e7d2c8',
#  'vista white 2': '#e3dfd9',
#  'marshmallow': '#fcdbd2',
#  'bridesmaid 2': '#fae6df',
#  'very pale vermilion': '#ffe9e2',
#  'asphalt 2': '#2a2922',
#  'banjul 2': '#34322d',
#  'maire 2': '#2a2922',
#  'nero 2': '#252525',
#  'creole 2': '#393227',
#  'very deep brown': '#1d0e00',
#  'graphite 2': '#383428',
#  'bokara grey 2': '#2a2725',
#  'crowshead 2': '#32312e',
#  'black magic 2': '#332c22',
#  'cannon black 2': '#332c22',
#  'smoky black': '#100c08',
#  'very brown': '#1d1711',
#  'marbaroda': '#3d312d',
#  'beer srm 26': '#721b00',
#  'dark vermilion': '#593427',
#  'teak wood finish': '#6b2a14',
#  'beer srm 24': '#7e1f01',
#  'sooty': '#281d19',
#  'bootleg': '#3c241b',
#  'brown pod 2': '#3c241b',
#  'chocolate brownie': '#3c241b',
#  'deep chocolate': '#3c241b',
#  'sofisticata': '#4e2d21',
#  'double felix': '#453732',
#  'timberland': '#4c332a',
#  'blackout': '#211916',
#  'double diesel': '#28201d',
#  'nala': '#412f28',
#  'cioccolato 2': '#5d3b2e',
#  'mission brown': '#443028',
#  'cosmonaut': '#26211f',
#  ...}

# %% [markdown]
# ## Convert to CSV for portability

# %%
with open('mkweb-colornames.csv', 'w') as f:
  f.write(f'name,hex\n')
  for name, hexcode in clean_colors.items():
    f.write(f'{name},{hexcode}\n')
